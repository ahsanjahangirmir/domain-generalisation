# %% [markdown]
# Evaluating VGG Model on a Independent and Identically Distributed Dataset

# %% [markdown]
# Making all required Imports

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
from tqdm import tqdm
import torchvision.models as models
import os
# from git import Repo
from PIL import Image
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# Loading In the VGG Model and setting up the device to see if we have a valid GPU available

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = models.vgg19(pretrained=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100%|██████████| 548M/548M [00:08<00:00, 67.5MB/s]

# %% [markdown]
# Getting The VGG Pretraind Model Ready for training.
#
# This step includes freezing all parameters in the feature extractor and replacing the classifier head with a new head based on the number of classes our dataset has which is 10 as CIFAR-10 dataset has 10 classes. We then define loss function and optimizer as. During this step we also move the model to our available device.

# %%
for param in model.parameters():
    param.requires_grad = False

num_ftrs = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_ftrs, 10)

model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.classifier[6].parameters(), lr=0.001)

# %% [markdown]
# In this step we define our Image transformation that we have to apply onto our CIFAR-10 Dataset. These transformations enhance the dataset and are helpful in Image classification. The outputed dataset with Image transformations applied is stored in the Variable trainset.
#
# We also get the trainloader which essentially splits train_dataset into batches or chunks. This can be helpful in making the model train more faster and smoother

# %%
transform = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

trainset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
trainloader = DataLoader(trainset, batch_size=32, shuffle=True, num_workers=4)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:04<00:00, 38746264.53it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# Training and Finetuning the VGG Model

# %% [markdown]
# In this step the VGG model is trained for 3 epochs. Essentially we will be doing a forward pass, calculating the loss and then updating the weights in the backward pass.

# %%
model.train()
num_epochs = 3

for epoch in range(num_epochs):
    running_loss = 0.0
    with tqdm(total=len(trainloader), desc=f'Epoch {epoch + 1}/{num_epochs}', unit='batch') as pbar:
        for i, (images, labels) in enumerate(trainloader):
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()

            outputs = model(images)
            loss = criterion(outputs, labels)

            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            pbar.set_postfix(loss=running_loss / (i + 1))
            pbar.update(1)

            if (i + 1) % 100 == 0:
                print(f'Epoch [{epoch + 1}], Step [{i + 1}], Loss: {running_loss / (i + 1):.4f}')
# Out:
# Epoch 1/3:   6%|▋         | 101/1563 [00:20<04:38,  5.25batch/s, loss=0.914]
# Epoch [1], Step [100], Loss: 0.9166
# Epoch 1/3:  13%|█▎        | 201/1563 [00:40<04:29,  5.05batch/s, loss=0.798]
# Epoch [1], Step [200], Loss: 0.7982
# Epoch 1/3:  19%|█▉        | 301/1563 [01:00<04:20,  4.84batch/s, loss=0.757]
# Epoch [1], Step [300], Loss: 0.7580
# Epoch 1/3:  26%|██▌       | 401/1563 [01:21<03:53,  4.98batch/s, loss=0.724]
# Epoch [1], Step [400], Loss: 0.7236
# Epoch 1/3:  32%|███▏      | 501/1563 [01:41<03:35,  4.94batch/s, loss=0.71]
# Epoch [1], Step [500], Loss: 0.7093
# Epoch 1/3:  38%|███▊      | 601/1563 [02:01<03:10,  5.04batch/s, loss=0.693]
# Epoch [1], Step [600], Loss: 0.6931
# Epoch 1/3:  45%|████▍     | 700/1563 [02:21<03:09,  4.55batch/s, loss=0.685]
# Epoch [1], Step [700], Loss: 0.6854
# Epoch 1/3:  51%|█████     | 800/1563 [02:41<02:33,  4.98batch/s, loss=0.678]
# Epoch [1], Step [800], Loss: 0.6778
# Epoch 1/3:  58%|█████▊    | 900/1563 [03:01<02:14,  4.94batch/s, loss=0.668]
# Epoch [1], Step [900], Loss: 0.6682
# Epoch 1/3:  64%|██████▍   | 1001/1563 [03:22<01:51,  5.02batch/s, loss=0.666]
# Epoch [1], Step [1000], Loss: 0.6664
# Epoch 1/3:  70%|███████   | 1101/1563 [03:42<01:32,  5.00batch/s, loss=0.665]
# Epoch [1], Step [1100], Loss: 0.6643
# Epoch 1/3:  77%|███████▋  | 1201/1563 [04:02<01:12,  5.02batch/s, loss=0.662]
# Epoch [1], Step [1200], Loss: 0.6619
# Epoch 1/3:  83%|████████▎ | 1301/1563 [04:22<00:52,  4.98batch/s, loss=0.663]
# Epoch [1], Step [1300], Loss: 0.6629
# Epoch 1/3:  90%|████████▉ | 1401/1563 [04:42<00:32,  4.97batch/s, loss=0.661]
# Epoch [1], Step [1400], Loss: 0.6610
# Epoch 1/3:  96%|█████████▌| 1501/1563 [05:02<00:12,  5.01batch/s, loss=0.66]
# Epoch [1], Step [1500], Loss: 0.6600
# Epoch 1/3: 100%|██████████| 1563/1563 [05:15<00:00,  4.96batch/s, loss=0.66]
# Epoch 2/3:   6%|▋         | 101/1563 [00:20<04:58,  4.89batch/s, loss=0.582]
# Epoch [2], Step [100], Loss: 0.5827
# Epoch 2/3:  13%|█▎        | 200/1563 [00:40<04:30,  5.04batch/s, loss=0.586]
# Epoch [2], Step [200], Loss: 0.5868
# Epoch 2/3:  19%|█▉        | 300/1563 [01:00<04:13,  4.98batch/s, loss=0.594]
# Epoch [2], Step [300], Loss: 0.5944
# Epoch 2/3:  26%|██▌       | 401/1563 [01:20<03:50,  5.04batch/s, loss=0.6]
# Epoch [2], Step [400], Loss: 0.5997
# Epoch 2/3:  32%|███▏      | 500/1563 [01:40<03:46,  4.69batch/s, loss=0.607]
# Epoch [2], Step [500], Loss: 0.6073
# Epoch 2/3:  38%|███▊      | 601/1563 [02:01<03:11,  5.03batch/s, loss=0.608]
# Epoch [2], Step [600], Loss: 0.6078
# Epoch 2/3:  45%|████▍     | 701/1563 [02:21<02:55,  4.92batch/s, loss=0.611]
# Epoch [2], Step [700], Loss: 0.6105
# Epoch 2/3:  51%|█████     | 800/1563 [02:41<02:32,  5.00batch/s, loss=0.612]
# Epoch [2], Step [800], Loss: 0.6116
# Epoch 2/3:  58%|█████▊    | 901/1563 [03:02<02:12,  5.01batch/s, loss=0.615]
# Epoch [2], Step [900], Loss: 0.6149
# Epoch 2/3:  64%|██████▍   | 1001/1563 [03:22<01:51,  5.03batch/s, loss=0.62]
# Epoch [2], Step [1000], Loss: 0.6198
# Epoch 2/3:  70%|███████   | 1101/1563 [03:42<01:32,  4.99batch/s, loss=0.624]
# Epoch [2], Step [1100], Loss: 0.6238
# Epoch 2/3:  77%|███████▋  | 1200/1563 [04:02<01:12,  4.98batch/s, loss=0.624]
# Epoch [2], Step [1200], Loss: 0.6238
# Epoch 2/3:  83%|████████▎ | 1301/1563 [04:22<00:52,  5.04batch/s, loss=0.626]
# Epoch [2], Step [1300], Loss: 0.6263
# Epoch 2/3:  90%|████████▉ | 1401/1563 [04:43<00:32,  4.94batch/s, loss=0.631]
# Epoch [2], Step [1400], Loss: 0.6304
# Epoch 2/3:  96%|█████████▌| 1501/1563 [05:03<00:12,  5.05batch/s, loss=0.634]
# Epoch [2], Step [1500], Loss: 0.6340
# Epoch 2/3: 100%|██████████| 1563/1563 [05:15<00:00,  4.95batch/s, loss=0.635]
# Epoch 3/3:   6%|▋         | 101/1563 [00:20<04:59,  4.88batch/s, loss=0.608]
# Epoch [3], Step [100], Loss: 0.6088
# Epoch 3/3:  13%|█▎        | 201/1563 [00:40<04:37,  4.90batch/s, loss=0.61]
# Epoch [3], Step [200], Loss: 0.6111
# Epoch 3/3:  19%|█▉        | 301/1563 [01:01<04:15,  4.94batch/s, loss=0.608]
# Epoch [3], Step [300], Loss: 0.6081
# Epoch 3/3:  26%|██▌       | 400/1563 [01:21<03:50,  5.05batch/s, loss=0.616]
# Epoch [3], Step [400], Loss: 0.6153
# Epoch 3/3:  32%|███▏      | 501/1563 [01:41<03:34,  4.96batch/s, loss=0.626]
# Epoch [3], Step [500], Loss: 0.6267
# Epoch 3/3:  38%|███▊      | 601/1563 [02:01<03:13,  4.96batch/s, loss=0.631]
# Epoch [3], Step [600], Loss: 0.6313
# Epoch 3/3:  45%|████▍     | 701/1563 [02:22<02:53,  4.96batch/s, loss=0.64]
# Epoch [3], Step [700], Loss: 0.6387
# Epoch 3/3:  51%|█████     | 801/1563 [02:42<02:33,  4.97batch/s, loss=0.642]
# Epoch [3], Step [800], Loss: 0.6410
# Epoch 3/3:  58%|█████▊    | 901/1563 [03:02<02:11,  5.04batch/s, loss=0.643]
# Epoch [3], Step [900], Loss: 0.6424
# Epoch 3/3:  64%|██████▍   | 1000/1563 [03:22<01:59,  4.71batch/s, loss=0.641]
# Epoch [3], Step [1000], Loss: 0.6410
# Epoch 3/3:  70%|███████   | 1100/1563 [03:43<01:32,  4.99batch/s, loss=0.642]
# Epoch [3], Step [1100], Loss: 0.6424
# Epoch 3/3:  77%|███████▋  | 1200/1563 [04:03<01:16,  4.74batch/s, loss=0.645]
# Epoch [3], Step [1200], Loss: 0.6448
# Epoch 3/3:  83%|████████▎ | 1301/1563 [04:23<00:53,  4.89batch/s, loss=0.644]
# Epoch [3], Step [1300], Loss: 0.6437
# Epoch 3/3:  90%|████████▉ | 1401/1563 [04:46<00:32,  4.94batch/s, loss=0.647]
# Epoch [3], Step [1400], Loss: 0.6467
# Epoch 3/3:  96%|█████████▌| 1501/1563 [05:06<00:12,  4.90batch/s, loss=0.644]
# Epoch [3], Step [1500], Loss: 0.6444
# Epoch 3/3: 100%|██████████| 1563/1563 [05:19<00:00,  4.89batch/s, loss=0.645]

# %% [markdown]
# Evaluation Step and Get Accuracy

# %% [markdown]
# In this step we define the test set as well as the test loader and make the predictions on our finetuned model and report our accuracy at the end

# %%
testset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=32, shuffle=False)

model.eval()
correct = 0
total = 0

with torch.no_grad():
    for images, labels in testloader:
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

cifar10acc = 100 * correct / total

print(f'Accuracy on CIFAR-10 test set: {100 * correct / total:.2f}%')
# Out:
# Accuracy on CIFAR-10 test set: 82.97%

# %% [markdown]
# # TASK 4 Inductive Biases of Models: Semantic Biases
#
# We will do the following:
#
# *   Use the vgg model (finetuned on CIFAR10) and validate on a variation of CIFAR10 that exhibits shape bias
# *   Use the vgg model (finetuned on CIFAR10) and validate on a variation of CIFAR10 that exhibits texture bias
# *   Finetune the vgg model on MNIST Dataset and the evaluate it on a colourized MNIST dataset to find the colour bias

# %%
repo_url = 'https://github.com/bdevans/CIFAR-10G.git'
clone_dir = 'CIFAR-10G'


if not os.path.exists(clone_dir):
    print("Cloning the CIFAR-10G repository...")
    Repo.clone_from(repo_url, clone_dir)
    print("Repository cloned successfully.")
else:
    print("Repository already exists. Skipping clone.")


data_dir = os.path.join(clone_dir, '224x224')
data_dir = 'CIFAR-10G/224x224'

transform = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])
# Out:
# Cloning the CIFAR-10G repository...
# Repository cloned successfully.

# %% [markdown]
# **SHAPE BIAS**

# %%
subdirs = ['contours', 'contours_inverted', 'line_drawings', 'line_drawings_inverted', 'silhouettes', 'silhouettes_inverted']
datasets_dict = {}
validation_loaders = {}
accuracy_dict = {}

for subdir in subdirs:
    dataset_path = os.path.join(data_dir, subdir)

    dataset = datasets.ImageFolder(root=dataset_path, transform=transform)
    dataset_size = len(dataset)
    val_size = int(0.2 * dataset_size)
    train_size = dataset_size - val_size
    train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

    # Load datasets into DataLoader
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=4)

    datasets_dict[subdir] = train_loader
    validation_loaders[subdir] = val_loader
    accuracy_dict[subdir] = []
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# Evaluating the model on each of the sub directories. We store the accuracy of the model for each directory for future calculations.

# %%
num_epochs = 3

for subdir, validation_loader in validation_loaders.items():
    print(f"Validating on {subdir} dataset")

    for epoch in range(num_epochs):
        model.eval()
        correct = 0
        total = 0

        with tqdm(total=len(validation_loader), desc=f'Epoch {epoch + 1}/{num_epochs}', unit='batch') as pbar:
            with torch.no_grad():
                running_loss = 0.0
                for i, (images, labels) in enumerate(validation_loader):

                    images, labels = images.to(device), labels.to(device)
                    outputs = model(images)
                    loss = criterion(outputs, labels)
                    running_loss += loss.item()


                    _, predicted = torch.max(outputs, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

                    pbar.set_postfix(loss=running_loss / (i + 1))
                    pbar.update(1)

        accuracy = 100 * correct / total
        accuracy_dict[subdir].append(accuracy)

        print(f"Validation Accuracy on {subdir} dataset after epoch {epoch + 1}: {accuracy:.2f}%")

    print(f"Finished validating on {subdir} dataset\n")



for subdir, accuracies in accuracy_dict.items():
    print(f"Validation accuracies for {subdir} dataset over {num_epochs} epochs: {accuracies}")
# Out:
# Validating on contours dataset
# Epoch 1/3: 100%|██████████| 1/1 [00:00<00:00,  2.53batch/s, loss=9.43]
# Validation Accuracy on contours dataset after epoch 1: 10.00%
# Epoch 2/3: 100%|██████████| 1/1 [00:00<00:00,  2.98batch/s, loss=9.43]
# Validation Accuracy on contours dataset after epoch 2: 10.00%
# Epoch 3/3: 100%|██████████| 1/1 [00:00<00:00,  2.82batch/s, loss=9.43]
# Validation Accuracy on contours dataset after epoch 3: 10.00%
# Finished validating on contours dataset
#
# Validating on contours_inverted dataset
# Epoch 1/3: 100%|██████████| 1/1 [00:00<00:00,  2.85batch/s, loss=5.67]
# Validation Accuracy on contours_inverted dataset after epoch 1: 15.00%
# Epoch 2/3: 100%|██████████| 1/1 [00:00<00:00,  2.86batch/s, loss=5.67]
# Validation Accuracy on contours_inverted dataset after epoch 2: 15.00%
# Epoch 3/3: 100%|██████████| 1/1 [00:00<00:00,  3.00batch/s, loss=5.67]
# Validation Accuracy on contours_inverted dataset after epoch 3: 15.00%
# Finished validating on contours_inverted dataset
#
# Validating on line_drawings dataset
# Epoch 1/3: 100%|██████████| 1/1 [00:00<00:00,  2.98batch/s, loss=4.95]
# Validation Accuracy on line_drawings dataset after epoch 1: 35.00%
# Epoch 2/3: 100%|██████████| 1/1 [00:00<00:00,  2.21batch/s, loss=4.95]
# Validation Accuracy on line_drawings dataset after epoch 2: 35.00%
# Epoch 3/3: 100%|██████████| 1/1 [00:00<00:00,  1.71batch/s, loss=4.95]
# Validation Accuracy on line_drawings dataset after epoch 3: 35.00%
# Finished validating on line_drawings dataset
#
# Validating on line_drawings_inverted dataset
# Epoch 1/3: 100%|██████████| 1/1 [00:00<00:00,  1.14batch/s, loss=4.67]
# Validation Accuracy on line_drawings_inverted dataset after epoch 1: 45.00%
# Epoch 2/3: 100%|██████████| 1/1 [00:00<00:00,  1.60batch/s, loss=4.67]
# Validation Accuracy on line_drawings_inverted dataset after epoch 2: 45.00%
# Epoch 3/3: 100%|██████████| 1/1 [00:00<00:00,  2.02batch/s, loss=4.67]
# Validation Accuracy on line_drawings_inverted dataset after epoch 3: 45.00%
# Finished validating on line_drawings_inverted dataset
#
# Validating on silhouettes dataset
# Epoch 1/3: 100%|██████████| 1/1 [00:00<00:00,  2.49batch/s, loss=5.02]
# Validation Accuracy on silhouettes dataset after epoch 1: 40.00%
# Epoch 2/3: 100%|██████████| 1/1 [00:00<00:00,  2.88batch/s, loss=5.02]
# Validation Accuracy on silhouettes dataset after epoch 2: 40.00%
# Epoch 3/3: 100%|██████████| 1/1 [00:00<00:00,  2.90batch/s, loss=5.02]
# Validation Accuracy on silhouettes dataset after epoch 3: 40.00%
# Finished validating on silhouettes dataset
#
# Validating on silhouettes_inverted dataset
# Epoch 1/3: 100%|██████████| 1/1 [00:00<00:00,  2.77batch/s, loss=9.11]
# Validation Accuracy on silhouettes_inverted dataset after epoch 1: 20.00%
# Epoch 2/3: 100%|██████████| 1/1 [00:00<00:00,  2.99batch/s, loss=9.11]
# Validation Accuracy on silhouettes_inverted dataset after epoch 2: 20.00%
# Epoch 3/3: 100%|██████████| 1/1 [00:00<00:00,  3.03batch/s, loss=9.11]
# Validation Accuracy on silhouettes_inverted dataset after epoch 3: 20.00%
# Finished validating on silhouettes_inverted dataset
#
# Validation accuracies for contours dataset over 3 epochs: [10.0, 10.0, 10.0]
# Validation accuracies for contours_inverted dataset over 3 epochs: [15.0, 15.0, 15.0]
# Validation accuracies for line_drawings dataset over 3 epochs: [35.0, 35.0, 35.0]
# Validation accuracies for line_drawings_inverted dataset over 3 epochs: [45.0, 45.0, 45.0]
# Validation accuracies for silhouettes dataset over 3 epochs: [40.0, 40.0, 40.0]
# Validation accuracies for silhouettes_inverted dataset over 3 epochs: [20.0, 20.0, 20.0]

# %% [markdown]
# Here we calculate the average accuracy of all the sub directories, then we use that average and the model's original accuracy on the CIFAR 10 dataset to calculate the shape bias of the vgg model.
# This is obtained via the formula: avg_accuracy/cifar10accuracy

# %%
total_accuracy_sum = 0
accuracy_count = 0

for subdir, accuracies in accuracy_dict.items():
    total_accuracy_sum += sum(accuracies)
    accuracy_count += len(accuracies)

average_accuracy = total_accuracy_sum / accuracy_count

final_value = average_accuracy / cifar10acc

print(f"Shape Bias using the CIFAR10G Dataset turn out to be: {final_value:.4f}")
# Out:
# Shape Bias using the CIFAR10G Dataset turn out to be: 0.3290

# %% [markdown]
# **TEXTURE BIAS:** This dataset is a variation of CIFAR10 with texture differences.

# %%
# !unzip texture_bias_dataset.zip
# Out:
# Archive:  texture_bias_dataset.zip
#    creating: airplane/
#    creating: automobile/
#    creating: bird/
#    creating: cat/
#    creating: deer/
#    creating: dog/
#    creating: frog/
#    creating: horse/
#    creating: ship/
#    creating: truck/
#   inflating: ship/094.png
#   inflating: ship/004.png
#   inflating: ship/031.png
#   inflating: ship/099.png
#   inflating: ship/037.png
#   inflating: ship/001.png
#   inflating: ship/097.png
#   inflating: ship/076.png
#   inflating: ship/100.png
#   inflating: ship/048.png
#   inflating: ship/007.png
#   inflating: ship/058.png
#   inflating: ship/056.png
#   inflating: ship/096.png
#   inflating: ship/079.png
#   inflating: ship/071.png
#   inflating: ship/026.png
#   inflating: ship/002.png
#   inflating: ship/068.png
#   inflating: ship/013.png
#   inflating: ship/043.png
#   inflating: ship/074.png
#   inflating: ship/059.png
#   inflating: ship/022.png
#   inflating: ship/020.png
#   inflating: ship/034.png
#   inflating: ship/028.png
#   inflating: ship/090.png
#   inflating: ship/025.png
#   inflating: ship/086.png
#   inflating: ship/039.png
#   inflating: ship/029.png
#   inflating: ship/070.png
#   inflating: ship/016.png
#   inflating: ship/093.png
#   inflating: ship/095.png
#   inflating: ship/023.png
#   inflating: ship/038.png
#   inflating: ship/054.png
#   inflating: ship/082.png
#   inflating: ship/084.png
#   inflating: ship/036.png
#   inflating: ship/005.png
#   inflating: ship/065.png
#   inflating: ship/049.png
#   inflating: ship/017.png
#   inflating: ship/083.png
#   inflating: ship/014.png
#   inflating: ship/035.png
#   inflating: ship/063.png
#   inflating: ship/051.png
#   inflating: ship/092.png
#   inflating: ship/046.png
#   inflating: ship/027.png
#   inflating: ship/024.png
#   inflating: ship/030.png
#   inflating: ship/066.png
#   inflating: ship/062.png
#   inflating: ship/078.png
#   inflating: ship/085.png
#   inflating: ship/041.png
#   inflating: ship/072.png
#   inflating: ship/052.png
#   inflating: ship/069.png
#   inflating: ship/045.png
#   inflating: ship/060.png
#   inflating: ship/015.png
#   inflating: ship/008.png
#   inflating: ship/040.png
#   inflating: ship/080.png
#   inflating: ship/012.png
#   inflating: ship/050.png
#   inflating: ship/011.png
#   inflating: ship/088.png
#   inflating: ship/047.png
#   inflating: ship/033.png
#   inflating: ship/075.png
#   inflating: ship/021.png
#   inflating: ship/089.png
#   inflating: ship/055.png
#   inflating: ship/081.png
#   inflating: ship/098.png
#   inflating: ship/091.png
#   inflating: ship/019.png
#   inflating: ship/042.png
#   inflating: ship/044.png
#   inflating: ship/087.png
#   inflating: ship/053.png
#   inflating: ship/006.png
#   inflating: ship/073.png
#   inflating: ship/010.png
#   inflating: ship/009.png
#   inflating: ship/077.png
#   inflating: ship/032.png
#   inflating: ship/067.png
#   inflating: ship/057.png
#   inflating: ship/064.png
#   inflating: ship/003.png
#   inflating: ship/061.png
#   inflating: ship/018.png
#   inflating: horse/094.png
#   inflating: horse/004.png
#   inflating: horse/031.png
#   inflating: horse/099.png
#   inflating: horse/037.png
#   inflating: horse/001.png
#   inflating: horse/097.png
#   inflating: horse/076.png
#   inflating: horse/100.png
#   inflating: horse/048.png
#   inflating: horse/007.png
#   inflating: horse/058.png
#   inflating: horse/056.png
#   inflating: horse/096.png
#   inflating: horse/079.png
#   inflating: horse/071.png
#   inflating: horse/026.png
#   inflating: horse/002.png
#   inflating: horse/068.png
#   inflating: horse/013.png
#   inflating: horse/043.png
#   inflating: horse/074.png
#   inflating: horse/059.png
#   inflating: horse/022.png
#   inflating: horse/020.png
#   inflating: horse/034.png
#   inflating: horse/028.png
#   inflating: horse/090.png
#   inflating: horse/025.png
#   inflating: horse/086.png
#   inflating: horse/039.png
#   inflating: horse/029.png
#   inflating: horse/070.png
#   inflating: horse/016.png
#   inflating: horse/093.png
#   inflating: horse/095.png
#   inflating: horse/023.png
#   inflating: horse/038.png
#   inflating: horse/054.png
#   inflating: horse/082.png
#   inflating: horse/084.png
#   inflating: horse/036.png
#   inflating: horse/005.png
#   inflating: horse/065.png
#   inflating: horse/049.png
#   inflating: horse/017.png
#   inflating: horse/083.png
#   inflating: horse/014.png
#   inflating: horse/035.png
#   inflating: horse/063.png
#   inflating: horse/051.png
#   inflating: horse/092.png
#   inflating: horse/046.png
#   inflating: horse/027.png
#   inflating: horse/024.png
#   inflating: horse/030.png
#   inflating: horse/066.png
#   inflating: horse/062.png
#   inflating: horse/078.png
#   inflating: horse/085.png
#   inflating: horse/041.png
#   inflating: horse/072.png
#   inflating: horse/052.png
#   inflating: horse/069.png
#   inflating: horse/045.png
#   inflating: horse/060.png
#   inflating: horse/015.png
#   inflating: horse/008.png
#   inflating: horse/040.png
#   inflating: horse/080.png
#   inflating: horse/012.png
#   inflating: horse/050.png
#   inflating: horse/011.png
#   inflating: horse/088.png
#   inflating: horse/047.png
#   inflating: horse/033.png
#   inflating: horse/075.png
#   inflating: horse/021.png
#   inflating: horse/089.png
#   inflating: horse/055.png
#   inflating: horse/081.png
#   inflating: horse/098.png
#   inflating: horse/091.png
#   inflating: horse/019.png
#   inflating: horse/042.png
#   inflating: horse/044.png
#   inflating: horse/087.png
#   inflating: horse/053.png
#   inflating: horse/006.png
#   inflating: horse/073.png
#   inflating: horse/010.png
#   inflating: horse/009.png
#   inflating: horse/077.png
#   inflating: horse/032.png
#   inflating: horse/067.png
#   inflating: horse/057.png
#   inflating: horse/064.png
#   inflating: horse/003.png
#   inflating: horse/061.png
#   inflating: horse/018.png
#   inflating: automobile/094.png
#   inflating: automobile/004.png
#   inflating: automobile/031.png
#   inflating: automobile/099.png
#   inflating: automobile/037.png
#   inflating: automobile/001.png
#   inflating: automobile/097.png
#   inflating: automobile/076.png
#   inflating: automobile/100.png
#   inflating: automobile/048.png
#   inflating: automobile/007.png
#   inflating: automobile/058.png
#   inflating: automobile/056.png
#   inflating: automobile/096.png
#   inflating: automobile/079.png
#   inflating: automobile/071.png
#   inflating: automobile/026.png
#   inflating: automobile/002.png
#   inflating: automobile/068.png
#   inflating: automobile/013.png
#   inflating: automobile/043.png
#   inflating: automobile/074.png
#   inflating: automobile/059.png
#   inflating: automobile/022.png
#   inflating: automobile/020.png
#   inflating: automobile/034.png
#   inflating: automobile/028.png
#   inflating: automobile/090.png
#   inflating: automobile/025.png
#   inflating: automobile/086.png
#   inflating: automobile/039.png
#   inflating: automobile/029.png
#   inflating: automobile/070.png
#   inflating: automobile/016.png
#   inflating: automobile/093.png
#   inflating: automobile/095.png
#   inflating: automobile/023.png
#   inflating: automobile/038.png
#   inflating: automobile/054.png
#   inflating: automobile/082.png
#   inflating: automobile/084.png
#   inflating: automobile/036.png
#   inflating: automobile/005.png
#   inflating: automobile/065.png
#   inflating: automobile/049.png
#   inflating: automobile/017.png
#   inflating: automobile/083.png
#   inflating: automobile/014.png
#   inflating: automobile/035.png
#   inflating: automobile/063.png
#   inflating: automobile/051.png
#   inflating: automobile/092.png
#   inflating: automobile/046.png
#   inflating: automobile/027.png
#   inflating: automobile/024.png
#   inflating: automobile/030.png
#   inflating: automobile/066.png
#   inflating: automobile/062.png
#   inflating: automobile/078.png
#   inflating: automobile/085.png
#   inflating: automobile/041.png
#   inflating: automobile/072.png
#   inflating: automobile/052.png
#   inflating: automobile/069.png
#   inflating: automobile/045.png
#   inflating: automobile/060.png
#   inflating: automobile/015.png
#   inflating: automobile/008.png
#   inflating: automobile/040.png
#   inflating: automobile/080.png
#   inflating: automobile/012.png
#   inflating: automobile/050.png
#   inflating: automobile/011.png
#   inflating: automobile/088.png
#   inflating: automobile/047.png
#   inflating: automobile/033.png
#   inflating: automobile/075.png
#   inflating: automobile/021.png
#   inflating: automobile/089.png
#   inflating: automobile/055.png
#   inflating: automobile/081.png
#   inflating: automobile/098.png
#   inflating: automobile/091.png
#   inflating: automobile/019.png
#   inflating: automobile/042.png
#   inflating: automobile/044.png
#   inflating: automobile/087.png
#   inflating: automobile/053.png
#   inflating: automobile/006.png
#   inflating: automobile/073.png
#   inflating: automobile/010.png
#   inflating: automobile/009.png
#   inflating: automobile/077.png
#   inflating: automobile/032.png
#   inflating: automobile/067.png
#   inflating: automobile/057.png
#   inflating: automobile/064.png
#   inflating: automobile/003.png
#   inflating: automobile/061.png
#   inflating: automobile/018.png
#   inflating: airplane/094.png
#   inflating: airplane/004.png
#   inflating: airplane/031.png
#   inflating: airplane/099.png
#   inflating: airplane/037.png
#   inflating: airplane/001.png
#   inflating: airplane/097.png
#   inflating: airplane/076.png
#   inflating: airplane/100.png
#   inflating: airplane/048.png
#   inflating: airplane/007.png
#   inflating: airplane/058.png
#   inflating: airplane/056.png
#   inflating: airplane/096.png
#   inflating: airplane/079.png
#   inflating: airplane/071.png
#   inflating: airplane/026.png
#   inflating: airplane/002.png
#   inflating: airplane/068.png
#   inflating: airplane/013.png
#   inflating: airplane/043.png
#   inflating: airplane/074.png
#   inflating: airplane/059.png
#   inflating: airplane/022.png
#   inflating: airplane/020.png
#   inflating: airplane/034.png
#   inflating: airplane/028.png
#   inflating: airplane/090.png
#   inflating: airplane/025.png
#   inflating: airplane/086.png
#   inflating: airplane/039.png
#   inflating: airplane/029.png
#   inflating: airplane/070.png
#   inflating: airplane/016.png
#   inflating: airplane/093.png
#   inflating: airplane/095.png
#   inflating: airplane/023.png
#   inflating: airplane/038.png
#   inflating: airplane/054.png
#   inflating: airplane/082.png
#   inflating: airplane/084.png
#   inflating: airplane/036.png
#   inflating: airplane/005.png
#   inflating: airplane/065.png
#   inflating: airplane/049.png
#   inflating: airplane/017.png
#   inflating: airplane/083.png
#   inflating: airplane/014.png
#   inflating: airplane/035.png
#   inflating: airplane/063.png
#   inflating: airplane/051.png
#   inflating: airplane/092.png
#   inflating: airplane/046.png
#   inflating: airplane/027.png
#   inflating: airplane/024.png
#   inflating: airplane/030.png
#   inflating: airplane/066.png
#   inflating: airplane/062.png
#   inflating: airplane/078.png
#   inflating: airplane/085.png
#   inflating: airplane/041.png
#   inflating: airplane/072.png
#   inflating: airplane/052.png
#   inflating: airplane/069.png
#   inflating: airplane/045.png
#   inflating: airplane/060.png
#   inflating: airplane/015.png
#   inflating: airplane/008.png
#   inflating: airplane/040.png
#   inflating: airplane/080.png
#   inflating: airplane/012.png
#   inflating: airplane/050.png
#   inflating: airplane/011.png
#   inflating: airplane/088.png
#   inflating: airplane/047.png
#   inflating: airplane/033.png
#   inflating: airplane/075.png
#   inflating: airplane/021.png
#   inflating: airplane/089.png
#   inflating: airplane/055.png
#   inflating: airplane/081.png
#   inflating: airplane/098.png
#   inflating: airplane/091.png
#   inflating: airplane/019.png
#   inflating: airplane/042.png
#   inflating: airplane/044.png
#   inflating: airplane/087.png
#   inflating: airplane/053.png
#   inflating: airplane/006.png
#   inflating: airplane/073.png
#   inflating: airplane/010.png
#   inflating: airplane/009.png
#   inflating: airplane/077.png
#   inflating: airplane/032.png
#   inflating: airplane/067.png
#   inflating: airplane/057.png
#   inflating: airplane/064.png
#   inflating: airplane/003.png
#   inflating: airplane/061.png
#   inflating: airplane/018.png
#   inflating: deer/094.png
#   inflating: deer/004.png
#   inflating: deer/031.png
#   inflating: deer/099.png
#   inflating: deer/037.png
#   inflating: deer/001.png
#   inflating: deer/097.png
#   inflating: deer/076.png
#   inflating: deer/100.png
#   inflating: deer/048.png
#   inflating: deer/007.png
#   inflating: deer/058.png
#   inflating: deer/056.png
#   inflating: deer/096.png
#   inflating: deer/079.png
#   inflating: deer/071.png
#   inflating: deer/026.png
#   inflating: deer/002.png
#   inflating: deer/068.png
#   inflating: deer/013.png
#   inflating: deer/043.png
#   inflating: deer/074.png
#   inflating: deer/059.png
#   inflating: deer/022.png
#   inflating: deer/020.png
#   inflating: deer/034.png
#   inflating: deer/028.png
#   inflating: deer/090.png
#   inflating: deer/025.png
#   inflating: deer/086.png
#   inflating: deer/039.png
#   inflating: deer/029.png
#   inflating: deer/070.png
#   inflating: deer/016.png
#   inflating: deer/093.png
#   inflating: deer/095.png
#   inflating: deer/023.png
#   inflating: deer/038.png
#   inflating: deer/054.png
#   inflating: deer/082.png
#   inflating: deer/084.png
#   inflating: deer/036.png
#   inflating: deer/005.png
#   inflating: deer/065.png
#   inflating: deer/049.png
#   inflating: deer/017.png
#   inflating: deer/083.png
#   inflating: deer/014.png
#   inflating: deer/035.png
#   inflating: deer/063.png
#   inflating: deer/051.png
#   inflating: deer/092.png
#   inflating: deer/046.png
#   inflating: deer/027.png
#   inflating: deer/024.png
#   inflating: deer/030.png
#   inflating: deer/066.png
#   inflating: deer/062.png
#   inflating: deer/078.png
#   inflating: deer/085.png
#   inflating: deer/041.png
#   inflating: deer/072.png
#   inflating: deer/052.png
#   inflating: deer/069.png
#   inflating: deer/045.png
#   inflating: deer/060.png
#   inflating: deer/015.png
#   inflating: deer/008.png
#   inflating: deer/040.png
#   inflating: deer/080.png
#   inflating: deer/012.png
#   inflating: deer/050.png
#   inflating: deer/011.png
#   inflating: deer/088.png
#   inflating: deer/047.png
#   inflating: deer/033.png
#   inflating: deer/075.png
#   inflating: deer/021.png
#   inflating: deer/089.png
#   inflating: deer/055.png
#   inflating: deer/081.png
#   inflating: deer/098.png
#   inflating: deer/091.png
#   inflating: deer/019.png
#   inflating: deer/042.png
#   inflating: deer/044.png
#   inflating: deer/087.png
#   inflating: deer/053.png
#   inflating: deer/006.png
#   inflating: deer/073.png
#   inflating: deer/010.png
#   inflating: deer/009.png
#   inflating: deer/077.png
#   inflating: deer/032.png
#   inflating: deer/067.png
#   inflating: deer/057.png
#   inflating: deer/064.png
#   inflating: deer/003.png
#   inflating: deer/061.png
#   inflating: deer/018.png
#   inflating: frog/094.png
#   inflating: frog/004.png
#   inflating: frog/031.png
#   inflating: frog/099.png
#   inflating: frog/037.png
#   inflating: frog/001.png
#   inflating: frog/097.png
#   inflating: frog/076.png
#   inflating: frog/100.png
#   inflating: frog/048.png
#   inflating: frog/007.png
#   inflating: frog/058.png
#   inflating: frog/056.png
#   inflating: frog/096.png
#   inflating: frog/079.png
#   inflating: frog/071.png
#   inflating: frog/026.png
#   inflating: frog/002.png
#   inflating: frog/068.png
#   inflating: frog/013.png
#   inflating: frog/043.png
#   inflating: frog/074.png
#   inflating: frog/059.png
#   inflating: frog/022.png
#   inflating: frog/020.png
#   inflating: frog/034.png
#   inflating: frog/028.png
#   inflating: frog/090.png
#   inflating: frog/025.png
#   inflating: frog/086.png
#   inflating: frog/039.png
#   inflating: frog/029.png
#   inflating: frog/070.png
#   inflating: frog/016.png
#   inflating: frog/093.png
#   inflating: frog/095.png
#   inflating: frog/023.png
#   inflating: frog/038.png
#   inflating: frog/054.png
#   inflating: frog/082.png
#   inflating: frog/084.png
#   inflating: frog/036.png
#   inflating: frog/005.png
#   inflating: frog/065.png
#   inflating: frog/049.png
#   inflating: frog/017.png
#   inflating: frog/083.png
#   inflating: frog/014.png
#   inflating: frog/035.png
#   inflating: frog/063.png
#   inflating: frog/051.png
#   inflating: frog/092.png
#   inflating: frog/046.png
#   inflating: frog/027.png
#   inflating: frog/024.png
#   inflating: frog/030.png
#   inflating: frog/066.png
#   inflating: frog/062.png
#   inflating: frog/078.png
#   inflating: frog/085.png
#   inflating: frog/041.png
#   inflating: frog/072.png
#   inflating: frog/052.png
#   inflating: frog/069.png
#   inflating: frog/045.png
#   inflating: frog/060.png
#   inflating: frog/015.png
#   inflating: frog/008.png
#   inflating: frog/040.png
#   inflating: frog/080.png
#   inflating: frog/012.png
#   inflating: frog/050.png
#   inflating: frog/011.png
#   inflating: frog/088.png
#   inflating: frog/047.png
#   inflating: frog/033.png
#   inflating: frog/075.png
#   inflating: frog/021.png
#   inflating: frog/089.png
#   inflating: frog/055.png
#   inflating: frog/081.png
#   inflating: frog/098.png
#   inflating: frog/091.png
#   inflating: frog/019.png
#   inflating: frog/042.png
#   inflating: frog/044.png
#   inflating: frog/087.png
#   inflating: frog/053.png
#   inflating: frog/006.png
#   inflating: frog/073.png
#   inflating: frog/010.png
#   inflating: frog/009.png
#   inflating: frog/077.png
#   inflating: frog/032.png
#   inflating: frog/067.png
#   inflating: frog/057.png
#   inflating: frog/064.png
#   inflating: frog/003.png
#   inflating: frog/061.png
#   inflating: frog/018.png
#   inflating: dog/094.png
#   inflating: dog/004.png
#   inflating: dog/031.png
#   inflating: dog/099.png
#   inflating: dog/037.png
#   inflating: dog/001.png
#   inflating: dog/097.png
#   inflating: dog/076.png
#   inflating: dog/100.png
#   inflating: dog/048.png
#   inflating: dog/007.png
#   inflating: dog/058.png
#   inflating: dog/056.png
#   inflating: dog/096.png
#   inflating: dog/079.png
#   inflating: dog/071.png
#   inflating: dog/026.png
#   inflating: dog/002.png
#   inflating: dog/068.png
#   inflating: dog/013.png
#   inflating: dog/043.png
#   inflating: dog/074.png
#   inflating: dog/059.png
#   inflating: dog/022.png
#   inflating: dog/020.png
#   inflating: dog/034.png
#   inflating: dog/028.png
#   inflating: dog/090.png
#   inflating: dog/025.png
#   inflating: dog/086.png
#   inflating: dog/039.png
#   inflating: dog/029.png
#   inflating: dog/070.png
#   inflating: dog/016.png
#   inflating: dog/093.png
#   inflating: dog/095.png
#   inflating: dog/023.png
#   inflating: dog/038.png
#   inflating: dog/054.png
#   inflating: dog/082.png
#   inflating: dog/084.png
#   inflating: dog/036.png
#   inflating: dog/005.png
#   inflating: dog/065.png
#   inflating: dog/049.png
#   inflating: dog/017.png
#   inflating: dog/083.png
#   inflating: dog/014.png
#   inflating: dog/035.png
#   inflating: dog/063.png
#   inflating: dog/051.png
#   inflating: dog/092.png
#   inflating: dog/046.png
#   inflating: dog/027.png
#   inflating: dog/024.png
#   inflating: dog/030.png
#   inflating: dog/066.png
#   inflating: dog/062.png
#   inflating: dog/078.png
#   inflating: dog/085.png
#   inflating: dog/041.png
#   inflating: dog/072.png
#   inflating: dog/052.png
#   inflating: dog/069.png
#   inflating: dog/045.png
#   inflating: dog/060.png
#   inflating: dog/015.png
#   inflating: dog/008.png
#   inflating: dog/040.png
#   inflating: dog/080.png
#   inflating: dog/012.png
#   inflating: dog/050.png
#   inflating: dog/011.png
#   inflating: dog/088.png
#   inflating: dog/047.png
#   inflating: dog/033.png
#   inflating: dog/075.png
#   inflating: dog/021.png
#   inflating: dog/089.png
#   inflating: dog/055.png
#   inflating: dog/081.png
#   inflating: dog/098.png
#   inflating: dog/091.png
#   inflating: dog/019.png
#   inflating: dog/042.png
#   inflating: dog/044.png
#   inflating: dog/087.png
#   inflating: dog/053.png
#   inflating: dog/006.png
#   inflating: dog/073.png
#   inflating: dog/010.png
#   inflating: dog/009.png
#   inflating: dog/077.png
#   inflating: dog/032.png
#   inflating: dog/067.png
#   inflating: dog/057.png
#   inflating: dog/064.png
#   inflating: dog/003.png
#   inflating: dog/061.png
#   inflating: dog/018.png
#   inflating: bird/094.png
#   inflating: bird/004.png
#   inflating: bird/031.png
#   inflating: bird/099.png
#   inflating: bird/037.png
#   inflating: bird/001.png
#   inflating: bird/097.png
#   inflating: bird/076.png
#   inflating: bird/100.png
#   inflating: bird/048.png
#   inflating: bird/007.png
#   inflating: bird/058.png
#   inflating: bird/056.png
#   inflating: bird/096.png
#   inflating: bird/079.png
#   inflating: bird/071.png
#   inflating: bird/026.png
#   inflating: bird/002.png
#   inflating: bird/068.png
#   inflating: bird/013.png
#   inflating: bird/043.png
#   inflating: bird/074.png
#   inflating: bird/059.png
#   inflating: bird/022.png
#   inflating: bird/020.png
#   inflating: bird/034.png
#   inflating: bird/028.png
#   inflating: bird/090.png
#   inflating: bird/025.png
#   inflating: bird/086.png
#   inflating: bird/039.png
#   inflating: bird/029.png
#   inflating: bird/070.png
#   inflating: bird/016.png
#   inflating: bird/093.png
#   inflating: bird/095.png
#   inflating: bird/023.png
#   inflating: bird/038.png
#   inflating: bird/054.png
#   inflating: bird/082.png
#   inflating: bird/084.png
#   inflating: bird/036.png
#   inflating: bird/005.png
#   inflating: bird/065.png
#   inflating: bird/049.png
#   inflating: bird/017.png
#   inflating: bird/083.png
#   inflating: bird/014.png
#   inflating: bird/035.png
#   inflating: bird/063.png
#   inflating: bird/051.png
#   inflating: bird/092.png
#   inflating: bird/046.png
#   inflating: bird/027.png
#   inflating: bird/024.png
#   inflating: bird/030.png
#   inflating: bird/066.png
#   inflating: bird/062.png
#   inflating: bird/078.png
#   inflating: bird/085.png
#   inflating: bird/041.png
#   inflating: bird/072.png
#   inflating: bird/052.png
#   inflating: bird/069.png
#   inflating: bird/045.png
#   inflating: bird/060.png
#   inflating: bird/015.png
#   inflating: bird/008.png
#   inflating: bird/040.png
#   inflating: bird/080.png
#   inflating: bird/012.png
#   inflating: bird/050.png
#   inflating: bird/011.png
#   inflating: bird/088.png
#   inflating: bird/047.png
#   inflating: bird/033.png
#   inflating: bird/075.png
#   inflating: bird/021.png
#   inflating: bird/089.png
#   inflating: bird/055.png
#   inflating: bird/081.png
#   inflating: bird/098.png
#   inflating: bird/091.png
#   inflating: bird/019.png
#   inflating: bird/042.png
#   inflating: bird/044.png
#   inflating: bird/087.png
#   inflating: bird/053.png
#   inflating: bird/006.png
#   inflating: bird/073.png
#   inflating: bird/010.png
#   inflating: bird/009.png
#   inflating: bird/077.png
#   inflating: bird/032.png
#   inflating: bird/067.png
#   inflating: bird/057.png
#   inflating: bird/064.png
#   inflating: bird/003.png
#   inflating: bird/061.png
#   inflating: bird/018.png
#   inflating: cat/094.png
#   inflating: cat/004.png
#   inflating: cat/031.png
#   inflating: cat/099.png
#   inflating: cat/037.png
#   inflating: cat/001.png
#   inflating: cat/097.png
#   inflating: cat/076.png
#   inflating: cat/100.png
#   inflating: cat/048.png
#   inflating: cat/007.png
#   inflating: cat/058.png
#   inflating: cat/056.png
#   inflating: cat/096.png
#   inflating: cat/079.png
#   inflating: cat/071.png
#   inflating: cat/026.png
#   inflating: cat/002.png
#   inflating: cat/068.png
#   inflating: cat/013.png
#   inflating: cat/043.png
#   inflating: cat/074.png
#   inflating: cat/059.png
#   inflating: cat/022.png
#   inflating: cat/020.png
#   inflating: cat/034.png
#   inflating: cat/028.png
#   inflating: cat/090.png
#   inflating: cat/025.png
#   inflating: cat/086.png
#   inflating: cat/039.png
#   inflating: cat/029.png
#   inflating: cat/070.png
#   inflating: cat/016.png
#   inflating: cat/093.png
#   inflating: cat/095.png
#   inflating: cat/023.png
#   inflating: cat/038.png
#   inflating: cat/054.png
#   inflating: cat/082.png
#   inflating: cat/084.png
#   inflating: cat/036.png
#   inflating: cat/005.png
#   inflating: cat/065.png
#   inflating: cat/049.png
#   inflating: cat/017.png
#   inflating: cat/083.png
#   inflating: cat/014.png
#   inflating: cat/035.png
#   inflating: cat/063.png
#   inflating: cat/051.png
#   inflating: cat/092.png
#   inflating: cat/046.png
#   inflating: cat/027.png
#   inflating: cat/024.png
#   inflating: cat/030.png
#   inflating: cat/066.png
#   inflating: cat/062.png
#   inflating: cat/078.png
#   inflating: cat/085.png
#   inflating: cat/041.png
#   inflating: cat/072.png
#   inflating: cat/052.png
#   inflating: cat/069.png
#   inflating: cat/045.png
#   inflating: cat/060.png
#   inflating: cat/015.png
#   inflating: cat/008.png
#   inflating: cat/040.png
#   inflating: cat/080.png
#   inflating: cat/012.png
#   inflating: cat/050.png
#   inflating: cat/011.png
#   inflating: cat/088.png
#   inflating: cat/047.png
#   inflating: cat/033.png
#   inflating: cat/075.png
#   inflating: cat/021.png
#   inflating: cat/089.png
#   inflating: cat/055.png
#   inflating: cat/081.png
#   inflating: cat/098.png
#   inflating: cat/091.png
#   inflating: cat/019.png
#   inflating: cat/042.png
#   inflating: cat/044.png
#   inflating: cat/087.png
#   inflating: cat/053.png
#   inflating: cat/006.png
#   inflating: cat/073.png
#   inflating: cat/010.png
#   inflating: cat/009.png
#   inflating: cat/077.png
#   inflating: cat/032.png
#   inflating: cat/067.png
#   inflating: cat/057.png
#   inflating: cat/064.png
#   inflating: cat/003.png
#   inflating: cat/061.png
#   inflating: cat/018.png
#   inflating: truck/094.png
#   inflating: truck/004.png
#   inflating: truck/031.png
#   inflating: truck/099.png
#   inflating: truck/037.png
#   inflating: truck/001.png
#   inflating: truck/097.png
#   inflating: truck/076.png
#   inflating: truck/100.png
#   inflating: truck/048.png
#   inflating: truck/007.png
#   inflating: truck/058.png
#   inflating: truck/056.png
#   inflating: truck/096.png
#   inflating: truck/079.png
#   inflating: truck/071.png
#   inflating: truck/026.png
#   inflating: truck/002.png
#   inflating: truck/068.png
#   inflating: truck/013.png
#   inflating: truck/043.png
#   inflating: truck/074.png
#   inflating: truck/059.png
#   inflating: truck/022.png
#   inflating: truck/020.png
#   inflating: truck/034.png
#   inflating: truck/028.png
#   inflating: truck/090.png
#   inflating: truck/025.png
#   inflating: truck/086.png
#   inflating: truck/039.png
#   inflating: truck/029.png
#   inflating: truck/070.png
#   inflating: truck/016.png
#   inflating: truck/093.png
#   inflating: truck/095.png
#   inflating: truck/023.png
#   inflating: truck/038.png
#   inflating: truck/054.png
#   inflating: truck/082.png
#   inflating: truck/084.png
#   inflating: truck/036.png
#   inflating: truck/005.png
#   inflating: truck/065.png
#   inflating: truck/049.png
#   inflating: truck/017.png
#   inflating: truck/083.png
#   inflating: truck/014.png
#   inflating: truck/035.png
#   inflating: truck/063.png
#   inflating: truck/051.png
#   inflating: truck/092.png
#   inflating: truck/046.png
#   inflating: truck/027.png
#   inflating: truck/024.png
#   inflating: truck/030.png
#   inflating: truck/066.png
#   inflating: truck/062.png
#   inflating: truck/078.png
#   inflating: truck/085.png
#   inflating: truck/041.png
#   inflating: truck/072.png
#   inflating: truck/052.png
#   inflating: truck/069.png
#   inflating: truck/045.png
#   inflating: truck/060.png
#   inflating: truck/015.png
#   inflating: truck/008.png
#   inflating: truck/040.png
#   inflating: truck/080.png
#   inflating: truck/012.png
#   inflating: truck/050.png
#   inflating: truck/011.png
#   inflating: truck/088.png
#   inflating: truck/047.png
#   inflating: truck/033.png
#   inflating: truck/075.png
#   inflating: truck/021.png
#   inflating: truck/089.png
#   inflating: truck/055.png
#   inflating: truck/081.png
#   inflating: truck/098.png
#   inflating: truck/091.png
#   inflating: truck/019.png
#   inflating: truck/042.png
#   inflating: truck/044.png
#   inflating: truck/087.png
#   inflating: truck/053.png
#   inflating: truck/006.png
#   inflating: truck/073.png
#   inflating: truck/010.png
#   inflating: truck/009.png
#   inflating: truck/077.png
#   inflating: truck/032.png
#   inflating: truck/067.png
#   inflating: truck/057.png
#   inflating: truck/064.png
#   inflating: truck/003.png
#   inflating: truck/061.png
#   inflating: truck/018.png

# %% [markdown]
# Our code uses a CIFAR10GCustomDataset class that reads the repo from github and creates a dataset that the vgg model is used to seeing and was trained on. furthermore, it divides the texture bias dataset into train and test splits, however we will only be using the test data.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
class CIFAR10GCustomDataset(Dataset):
    def __init__(self, root_dir, class_map, transform=None):
        self.root_dir = root_dir
        self.class_map = class_map
        self.transform = transform
        self.image_paths = []
        self.labels = []

        for class_name, class_idx in class_map.items():
            class_dir = os.path.join(root_dir, class_name)
            for img_name in os.listdir(class_dir):
                img_path = os.path.join(class_dir, img_name)
                self.image_paths.append(img_path)
                self.labels.append(class_idx)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        label = self.labels[idx]
        image = Image.open(img_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, label

data_dir = './'

# Mapping folder names to class indices (CIFAR-10 class names)
class_map = {
    'airplane': 0,
    'automobile': 1,
    'bird': 2,
    'cat': 3,
    'deer': 4,
    'dog': 5,
    'frog': 6,
    'horse': 7,
    'ship': 8,
    'truck': 9
}

transform = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

dataset = CIFAR10GCustomDataset(root_dir=data_dir, class_map=class_map, transform=transform)
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=4)

# %% [markdown]
# Here we evaluate the vgg model trained on CIFAR10 on the data which has texture changes.

# %%
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for images, labels in tqdm(val_loader, desc="Validating", unit="batch"):
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f'Validation Accuracy: {accuracy:.2f}%')
print("Texture Bias is: ", accuracy/cifar10acc)
# Out:
# Validating: 100%|██████████| 7/7 [00:01<00:00,  4.69batch/s]
# Validation Accuracy: 37.50%
# Texture Bias is:  0.4486719310839914

# %% [markdown]
# **COLOUR BIAS**. in the following cell we do:
#
# *   Load the MNIST dataset
# *   Freeze the model's backbone and get it ready for finetuning
# *   Divide the dataset into training and test sets

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
transform = transforms.Compose([
    transforms.Resize(224),
    transforms.Grayscale(3),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
trainloader = DataLoader(trainset, batch_size=32, shuffle=True, num_workers=4)

valset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)
valloader = DataLoader(valset, batch_size=32, shuffle=False, num_workers=4)

model2 = models.vgg19(weights=models.VGG19_Weights.IMAGENET1K_V1)


for param in model2.parameters():
    param.requires_grad = False


num_ftrs = model2.classifier[6].in_features
model2.classifier[6] = nn.Linear(num_ftrs, 10)

model2.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model2.classifier[6].parameters(), lr=0.001)

# %% [markdown]
# Here we start finetuning the vgg model for 3 epochs

# %%
num_epochs = 3
model2.train()

for epoch in range(num_epochs):
    running_loss = 0.0
    with tqdm(total=len(trainloader), desc=f'Epoch {epoch + 1}/{num_epochs}', unit='batch') as pbar:
        for i, (images, labels) in enumerate(trainloader):

            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()

            outputs = model2(images)

            loss = criterion(outputs, labels)

            loss.backward()

            optimizer.step()

            running_loss += loss.item()

            pbar.set_postfix(loss=running_loss / (i + 1))
            pbar.update(1)

    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {running_loss / len(trainloader):.4f}')

print("Training complete!")
# Out:
# Epoch 1/3: 100%|██████████| 1875/1875 [05:51<00:00,  5.33batch/s, loss=0.479]
# Epoch [1/3], Loss: 0.4792
# Epoch 2/3: 100%|██████████| 1875/1875 [05:55<00:00,  5.28batch/s, loss=0.391]
# Epoch [2/3], Loss: 0.3908
# Epoch 3/3: 100%|██████████| 1875/1875 [05:55<00:00,  5.27batch/s, loss=0.378]
# Epoch [3/3], Loss: 0.3780
# Training complete!

# %% [markdown]
# Here we validate on the MNIST test set to check whether our model was properly trained or not

# %%
model2.eval()
correct = 0
total = 0
with torch.no_grad():
    for images, labels in tqdm(valloader, desc="Validating", unit="batch"):
        images, labels = images.to(device), labels.to(device)

        outputs = model2(images)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f'Validation Accuracy: {accuracy:.2f}%')
# Out:
# Validating: 100%|██████████| 313/313 [00:59<00:00,  5.24batch/s]
# Validation Accuracy: 94.54%

# %% [markdown]
# Now we repeat the process but this time we use the colourized MNIST dataset and we avoid finetuning on this new dataset

# %%
repo_url = 'https://github.com/jayaneetha/colorized-MNIST.git'
clone_dir = 'colorized-MNIST'

if not os.path.exists(clone_dir):
    print("Cloning the colorized MNIST repository...")
    Repo.clone_from(repo_url, clone_dir)
    print("Repository cloned successfully.")
else:
    print("Repository already exists. Skipping clone.")

test_data_dir = os.path.join(clone_dir, 'testing')

transform_color = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

colorized_mnist_test = datasets.ImageFolder(root=test_data_dir, transform=transform_color)
testloader = DataLoader(colorized_mnist_test, batch_size=32, shuffle=False, num_workers=4)
# Out:
# Cloning the colorized MNIST repository...
# Repository cloned successfully.
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# We evaluate our model (trained on MNIST) on the colourized MNIST dataset to observe colour biases.
#
#
# *   colour bias = colorizedMNISTaccuracy/MNISTaccuracy

# %%
model2.eval()

correct = 0
total = 0
with torch.no_grad():
    for images, labels in tqdm(testloader, desc="Evaluating on Colorized MNIST", unit="batch"):
        images, labels = images.to(device), labels.to(device)
        outputs = model2(images)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy2 = 100 * correct / total
print(f'Accuracy on Colorized MNIST test set: {accuracy2:.2f}%')
# Out:
# Evaluating on Colorized MNIST: 100%|██████████| 313/313 [00:58<00:00,  5.35batch/s]
# Accuracy on Colorized MNIST test set: 38.45%

# %%
color_bias = accuracy2/accuracy
print("The colour bias is: ",color_bias)
# Out:
# The colour bias is:  0.4067061561243918

# %% [markdown]
# #  TASK 5 Inductive Biases of Models: Locality Biases

# %%
# !unzip noised_cifar10_test.zip
# Out:
# unzip:  cannot find or open noised_cifar10_test.zip, noised_cifar10_test.zip.zip or noised_cifar10_test.zip.ZIP.

# %% [markdown]
# Now we will use more variations of the CIFAR10 dataset to notice the effects of different biases on the accuracy of a model
#
# *   We will once again use a CIFAR10GCustomDataset class that converts our modified cifar10 dataset into a form that our model understands
# *   We also use this entire dataset as testing data as we do not have to finetune our model on these sets again

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
class CIFAR10GCustomDataset(Dataset):
    def __init__(self, root_dir, class_map, transform=None):
        self.root_dir = root_dir
        self.class_map = class_map
        self.transform = transform
        self.image_paths = []
        self.labels = []

        for class_name, class_idx in class_map.items():
            class_dir = os.path.join(root_dir, class_name)
            for img_name in os.listdir(class_dir):
                img_path = os.path.join(class_dir, img_name)
                self.image_paths.append(img_path)
                self.labels.append(class_idx)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        label = self.labels[idx]
        image = Image.open(img_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, label

data_dir = './'

# Mapping folder names to class indices (CIFAR-10 class names)
class_map = {
    'airplane': 0,
    'automobile': 1,
    'bird': 2,
    'cat': 3,
    'deer': 4,
    'dog': 5,
    'frog': 6,
    'horse': 7,
    'ship': 8,
    'truck': 9
}

transform = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

dataset = CIFAR10GCustomDataset(root_dir=data_dir, class_map=class_map, transform=transform)
test_loader = DataLoader(dataset, batch_size=32, shuffle=False, num_workers=4)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-51c0f9eb2a37> in <cell line: 52>()
#      50 ])
#      51
# ---> 52 dataset = CIFAR10GCustomDataset(root_dir=data_dir, class_map=class_map, transform=transform)
#      53 test_loader = DataLoader(dataset, batch_size=32, shuffle=False, num_workers=4)
#
# <ipython-input-12-51c0f9eb2a37> in __init__(self, root_dir, class_map, transform)
#      10         for class_name, class_idx in class_map.items():
#      11             class_dir = os.path.join(root_dir, class_name)
# ---> 12             for img_name in os.listdir(class_dir):
#      13                 img_path = os.path.join(class_dir, img_name)
#      14                 self.image_paths.append(img_path)
#
# FileNotFoundError: [Errno 2] No such file or directory: './airplane'

# %% [markdown]
# Here we validate the model on this dataset with added noise. we will then compare the accuracies with and without noise in the cifar10 dataset and evaluate how much the accuracy drops of our model

# %%
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for images, labels in tqdm(test_loader, desc="Validating", unit="batch"):

        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f'Validation Accuracy: {accuracy:.2f}%')
print("Change in accuracy: ", cifar10acc - accuracy)
# Out:
# Validating: 100%|██████████| 313/313 [00:58<00:00,  5.34batch/s]
# Validation Accuracy: 67.06%
# Change in accuracy:  16.519999999999996

# %%
# !unzip scrambled_cifar10_test.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ship/4361.png
#   inflating: ship/8785.png
#   inflating: ship/2874.png
#   inflating: ship/4846.png
#   inflating: ship/4351.png
#   inflating: ship/3848.png
#   inflating: ship/4769.png
#   inflating: ship/202.png
#   inflating: ship/7144.png
#   inflating: ship/8704.png
#   inflating: ship/4497.png
#   inflating: ship/1366.png
#   inflating: ship/6691.png
#   inflating: ship/9720.png
#   inflating: ship/5879.png
#   inflating: ship/6961.png
#   inflating: ship/6747.png
#   inflating: ship/8608.png
#   inflating: ship/8303.png
#   inflating: ship/6474.png
#   inflating: ship/3243.png
#   inflating: ship/4389.png
#   inflating: ship/1897.png
#   inflating: ship/8208.png
#   inflating: ship/1358.png
#   inflating: ship/8867.png
#   inflating: ship/7515.png
#   inflating: ship/54.png
#   inflating: ship/3380.png
#   inflating: ship/1866.png
#   inflating: ship/615.png
#   inflating: ship/1600.png
#   inflating: ship/909.png
#   inflating: ship/8182.png
#   inflating: ship/3803.png
#   inflating: ship/2847.png
#   inflating: ship/2254.png
#   inflating: ship/2153.png
#   inflating: ship/2687.png
#   inflating: ship/8696.png
#   inflating: ship/8409.png
#   inflating: ship/4165.png
#   inflating: ship/7307.png
#   inflating: ship/51.png
#   inflating: ship/274.png
#   inflating: ship/8067.png
#   inflating: ship/3829.png
#   inflating: ship/6556.png
#   inflating: ship/4486.png
#   inflating: ship/7564.png
#   inflating: ship/5503.png
#   inflating: ship/4492.png
#   inflating: ship/2539.png
#   inflating: ship/492.png
#   inflating: ship/3089.png
#   inflating: ship/4585.png
#   inflating: ship/2431.png
#   inflating: ship/3870.png
#   inflating: ship/5205.png
#   inflating: ship/3643.png
#   inflating: ship/4068.png
#   inflating: ship/1499.png
#   inflating: ship/3350.png
#   inflating: ship/2737.png
#   inflating: ship/3718.png
#   inflating: ship/3206.png
#   inflating: ship/5257.png
#   inflating: ship/7808.png
#   inflating: ship/8676.png
#   inflating: ship/1347.png
#   inflating: ship/4496.png
#   inflating: ship/1281.png
#   inflating: ship/6766.png
#   inflating: ship/9930.png
#   inflating: ship/6702.png
#   inflating: ship/6611.png
#   inflating: ship/2052.png
#   inflating: ship/8561.png
#   inflating: ship/3912.png
#   inflating: ship/6613.png
#   inflating: ship/8158.png
#   inflating: ship/2591.png
#   inflating: ship/2380.png
#   inflating: ship/2621.png
#   inflating: ship/1946.png
#   inflating: ship/344.png
#   inflating: ship/576.png
#   inflating: ship/6541.png
#   inflating: ship/312.png
#   inflating: ship/3189.png
#   inflating: ship/4787.png
#   inflating: ship/6716.png
#   inflating: ship/8234.png
#   inflating: ship/8968.png
#   inflating: ship/2533.png
#   inflating: ship/4651.png
#   inflating: ship/9296.png
#   inflating: ship/2837.png
#   inflating: ship/7055.png
#   inflating: ship/7984.png
#   inflating: ship/3871.png
#   inflating: ship/3552.png
#   inflating: ship/6412.png
#   inflating: ship/3807.png
#   inflating: ship/6000.png
#   inflating: ship/4599.png
#   inflating: ship/6602.png
#   inflating: ship/4944.png
#   inflating: ship/6526.png
#   inflating: ship/8228.png
#   inflating: ship/4720.png
#   inflating: ship/5672.png
#   inflating: ship/5989.png
#   inflating: ship/4919.png
#   inflating: ship/8373.png
#   inflating: ship/8189.png
#   inflating: ship/1164.png
#   inflating: ship/1349.png
#   inflating: ship/4223.png
#   inflating: ship/9474.png
#   inflating: ship/3641.png
#   inflating: ship/8287.png
#   inflating: ship/7682.png
#   inflating: ship/6211.png
#   inflating: ship/6689.png
#   inflating: ship/6217.png
#   inflating: ship/1557.png
#   inflating: ship/8883.png
#   inflating: ship/2546.png
#   inflating: ship/3854.png
#   inflating: ship/8239.png
#   inflating: ship/4008.png
#   inflating: ship/18.png
#   inflating: ship/3106.png
#   inflating: ship/2927.png
#   inflating: ship/939.png
#   inflating: ship/633.png
#   inflating: ship/2941.png
#   inflating: ship/1998.png
#   inflating: ship/9936.png
#   inflating: ship/3273.png
#   inflating: ship/717.png
#   inflating: ship/6052.png
#   inflating: ship/5104.png
#   inflating: ship/4142.png
#   inflating: ship/4316.png
#   inflating: ship/3109.png
#   inflating: ship/1895.png
#   inflating: ship/8125.png
#   inflating: ship/7441.png
#   inflating: ship/3858.png
#   inflating: ship/4961.png
#   inflating: ship/2295.png
#   inflating: ship/8046.png
#   inflating: ship/9864.png
#   inflating: ship/9466.png
#   inflating: ship/2429.png
#   inflating: ship/6947.png
#   inflating: ship/1497.png
#   inflating: ship/4085.png
#   inflating: ship/1311.png
#   inflating: ship/757.png
#   inflating: ship/8195.png
#   inflating: ship/6244.png
#   inflating: ship/9650.png
#   inflating: ship/712.png
#   inflating: ship/696.png
#   inflating: ship/3301.png
#   inflating: ship/1968.png
#   inflating: ship/996.png
#   inflating: ship/73.png
#   inflating: ship/2644.png
#   inflating: ship/9988.png
#   inflating: ship/2910.png
#   inflating: ship/2217.png
#   inflating: ship/3357.png
#   inflating: ship/8541.png
#   inflating: ship/4609.png
#   inflating: ship/9440.png
#   inflating: ship/5758.png
#   inflating: ship/6734.png
#   inflating: ship/5663.png
#   inflating: ship/2578.png
#   inflating: ship/3519.png
#   inflating: ship/1891.png
#   inflating: ship/5990.png
#   inflating: ship/404.png
#   inflating: ship/164.png
#   inflating: ship/1632.png
#   inflating: ship/1113.png
#   inflating: ship/4141.png
#   inflating: ship/3270.png
#   inflating: ship/2347.png
#   inflating: ship/5548.png
#   inflating: ship/6429.png
#   inflating: ship/1264.png
#   inflating: ship/5140.png
#   inflating: ship/260.png
#   inflating: ship/6348.png
#   inflating: ship/8470.png
#   inflating: ship/9834.png
#   inflating: ship/2553.png
#   inflating: ship/3423.png
#   inflating: ship/8154.png
#   inflating: ship/6839.png
#   inflating: ship/9490.png
#   inflating: ship/613.png
#   inflating: ship/6049.png
#   inflating: ship/1659.png
#   inflating: ship/5972.png
#   inflating: ship/6997.png
#   inflating: ship/9000.png
#   inflating: ship/8872.png
#   inflating: ship/4103.png
#   inflating: ship/7250.png
#   inflating: ship/2921.png
#   inflating: ship/6779.png
#   inflating: ship/7194.png
#   inflating: ship/6999.png
#   inflating: ship/7358.png
#   inflating: ship/7922.png
#   inflating: ship/7106.png
#   inflating: ship/55.png
#   inflating: ship/8969.png
#   inflating: ship/3686.png
#   inflating: ship/1447.png
#   inflating: ship/6295.png
#   inflating: ship/4517.png
#   inflating: ship/959.png
#   inflating: ship/8701.png
#   inflating: ship/7949.png
#   inflating: ship/3937.png
#   inflating: ship/1011.png
#   inflating: ship/7176.png
#   inflating: ship/926.png
#   inflating: ship/8757.png
#   inflating: ship/1284.png
#   inflating: ship/1826.png
#   inflating: ship/5249.png
#   inflating: ship/2458.png
#   inflating: ship/4317.png
#   inflating: ship/7320.png
#   inflating: ship/3008.png
#   inflating: ship/5993.png
#   inflating: ship/8905.png
#   inflating: ship/9176.png
#   inflating: ship/3763.png
#   inflating: ship/7042.png
#   inflating: ship/6831.png
#   inflating: ship/9275.png
#   inflating: ship/7503.png
#   inflating: ship/2502.png
#   inflating: ship/9697.png
#   inflating: ship/1139.png
#   inflating: ship/4870.png
#   inflating: ship/88.png
#   inflating: ship/7030.png
#   inflating: ship/875.png
#   inflating: ship/8101.png
#   inflating: ship/1488.png
#   inflating: ship/2118.png
#   inflating: ship/8520.png
#   inflating: ship/5526.png
#   inflating: ship/1369.png
#   inflating: ship/5427.png
#   inflating: ship/2064.png
#   inflating: ship/8530.png
#   inflating: ship/8951.png
#   inflating: ship/358.png
#   inflating: ship/8688.png
#   inflating: ship/6039.png
#   inflating: ship/5748.png
#   inflating: ship/9806.png
#   inflating: ship/1407.png
#   inflating: ship/4024.png
#   inflating: ship/173.png
#   inflating: ship/9914.png
#   inflating: ship/1742.png
#   inflating: ship/9028.png
#   inflating: ship/3155.png
#   inflating: ship/348.png
#   inflating: ship/7559.png
#   inflating: ship/7637.png
#   inflating: ship/4347.png
#   inflating: ship/8501.png
#   inflating: ship/6028.png
#   inflating: ship/8826.png
#   inflating: ship/8717.png
#   inflating: ship/949.png
#   inflating: ship/2624.png
#   inflating: ship/8875.png
#   inflating: ship/516.png
#   inflating: ship/5612.png
#   inflating: ship/9655.png
#   inflating: ship/9361.png
#   inflating: ship/6433.png
#   inflating: ship/8762.png
#   inflating: ship/6998.png
#   inflating: ship/9101.png
#   inflating: ship/2437.png
#   inflating: ship/9476.png
#   inflating: ship/6463.png
#   inflating: ship/1886.png
#   inflating: ship/8013.png
#   inflating: ship/1713.png
#   inflating: ship/2790.png
#   inflating: ship/9115.png
#   inflating: ship/1200.png
#   inflating: ship/2014.png
#   inflating: ship/789.png
#   inflating: ship/6238.png
#   inflating: ship/5342.png
#   inflating: ship/2721.png
#   inflating: ship/9908.png
#   inflating: ship/4079.png
#   inflating: ship/2048.png
#   inflating: ship/4409.png
#   inflating: ship/7409.png
#   inflating: ship/7768.png
#   inflating: ship/7088.png
#   inflating: ship/9291.png
#   inflating: ship/15.png
#   inflating: ship/7688.png
#   inflating: ship/8278.png
#   inflating: ship/3140.png
#   inflating: ship/1721.png
#   inflating: ship/7968.png
#   inflating: ship/166.png
#   inflating: ship/3695.png
#   inflating: ship/2893.png
#   inflating: ship/3705.png
#   inflating: ship/1263.png
#   inflating: ship/1459.png
#   inflating: ship/852.png
#   inflating: ship/3021.png
#   inflating: ship/4807.png
#   inflating: ship/385.png
#   inflating: ship/8888.png
#   inflating: ship/5188.png
#   inflating: ship/234.png
#   inflating: ship/1253.png
#   inflating: ship/6449.png
#   inflating: ship/1843.png
#   inflating: ship/6231.png
#   inflating: ship/721.png
#   inflating: ship/1556.png
#   inflating: ship/7913.png
#   inflating: ship/1242.png
#   inflating: ship/582.png
#   inflating: ship/8133.png
#   inflating: ship/1840.png
#   inflating: ship/9600.png
#   inflating: ship/1430.png
#   inflating: ship/1153.png
#   inflating: ship/519.png
#   inflating: ship/3585.png
#   inflating: ship/7542.png
#   inflating: ship/2265.png
#   inflating: ship/588.png
#   inflating: ship/8913.png
#   inflating: ship/2374.png
#   inflating: ship/9083.png
#   inflating: ship/818.png
#   inflating: ship/8690.png
#   inflating: ship/9617.png
#   inflating: ship/3968.png
#   inflating: ship/7860.png
#   inflating: ship/709.png
#   inflating: ship/5197.png
#   inflating: ship/683.png
#   inflating: ship/8361.png
#   inflating: ship/2957.png
#   inflating: ship/8760.png
#   inflating: ship/5946.png
#   inflating: ship/9203.png
#   inflating: ship/5110.png
#   inflating: ship/8146.png
#   inflating: ship/6342.png
#   inflating: ship/4254.png
#   inflating: ship/9127.png
#   inflating: ship/4986.png
#   inflating: ship/1213.png
#   inflating: ship/5078.png
#   inflating: ship/1683.png
#   inflating: ship/2476.png
#   inflating: ship/6286.png
#   inflating: ship/5619.png
#   inflating: ship/9725.png
#   inflating: ship/199.png
#   inflating: ship/7977.png
#   inflating: ship/2692.png
#   inflating: ship/3303.png
#   inflating: ship/4566.png
#   inflating: ship/2705.png
#   inflating: ship/6468.png
#   inflating: ship/5142.png
#   inflating: ship/1007.png
#   inflating: ship/3051.png
#   inflating: ship/9023.png
#   inflating: ship/1142.png
#   inflating: ship/6737.png
#   inflating: ship/8921.png
#   inflating: ship/6489.png
#   inflating: ship/7601.png
#   inflating: ship/1383.png
#   inflating: ship/4512.png
#   inflating: ship/5034.png
#   inflating: ship/265.png
#   inflating: ship/6346.png
#   inflating: ship/2456.png
#   inflating: ship/9239.png
#   inflating: ship/2898.png
#   inflating: ship/9680.png
#   inflating: ship/4242.png
#   inflating: ship/5073.png
#   inflating: ship/1102.png
#   inflating: ship/2418.png
#   inflating: ship/6937.png
#   inflating: ship/4428.png
#   inflating: ship/9538.png
#   inflating: ship/5688.png
#   inflating: ship/2354.png
#   inflating: ship/6718.png
#   inflating: ship/7296.png
#   inflating: ship/7404.png
#   inflating: ship/708.png
#   inflating: ship/8290.png
#   inflating: ship/6975.png
#   inflating: ship/2198.png
#   inflating: ship/6569.png
#   inflating: ship/4742.png
#   inflating: ship/79.png
#   inflating: ship/6262.png
#   inflating: ship/1294.png
#   inflating: ship/1655.png
#   inflating: ship/9175.png
#   inflating: ship/9784.png
#   inflating: ship/4735.png
#   inflating: ship/4229.png
#   inflating: ship/472.png
#   inflating: ship/4621.png
#   inflating: ship/4568.png
#   inflating: ship/4348.png
#   inflating: ship/8132.png
#   inflating: ship/7468.png
#   inflating: ship/2266.png
#   inflating: ship/7231.png
#   inflating: ship/9285.png
#   inflating: ship/8226.png
#   inflating: ship/9619.png
#   inflating: ship/4296.png
#   inflating: ship/1671.png
#   inflating: ship/3042.png
#   inflating: ship/806.png
#   inflating: ship/1691.png
#   inflating: ship/7675.png
#   inflating: ship/8311.png
#   inflating: ship/3182.png
#   inflating: ship/9713.png
#   inflating: ship/4124.png
#   inflating: ship/6466.png
#   inflating: ship/4196.png
#   inflating: ship/197.png
#   inflating: ship/1869.png
#   inflating: ship/6810.png
#   inflating: ship/1127.png
#   inflating: ship/132.png
#   inflating: ship/2451.png
#   inflating: ship/2471.png
#   inflating: ship/1648.png
#   inflating: ship/3521.png
#   inflating: ship/9736.png
#   inflating: ship/5325.png
#   inflating: ship/8516.png
#   inflating: ship/4582.png
#   inflating: ship/6414.png
#   inflating: ship/185.png
#   inflating: ship/2480.png
#   inflating: ship/7050.png
#   inflating: ship/4670.png
#   inflating: ship/7833.png
#   inflating: ship/7353.png
#   inflating: ship/2996.png
#   inflating: ship/6486.png
#   inflating: ship/8015.png
#   inflating: ship/9963.png
#   inflating: ship/6968.png
#   inflating: ship/1075.png
#   inflating: ship/7060.png
#   inflating: ship/4260.png
#   inflating: ship/495.png
#   inflating: ship/1279.png
#   inflating: ship/5095.png
#   inflating: ship/8117.png
#   inflating: ship/2579.png
#   inflating: ship/5383.png
#   inflating: ship/5230.png
#   inflating: ship/880.png
#   inflating: ship/1271.png
#   inflating: ship/191.png
#   inflating: ship/6285.png
#   inflating: ship/904.png
#   inflating: ship/9814.png
#   inflating: ship/2980.png
#   inflating: ship/3537.png
#   inflating: ship/3586.png
#   inflating: ship/108.png
#   inflating: ship/2503.png
#   inflating: ship/1874.png
#   inflating: ship/7724.png
#   inflating: ship/8567.png
#   inflating: ship/1.png
#   inflating: ship/4020.png
#   inflating: ship/5628.png
#   inflating: ship/6343.png
#   inflating: ship/8838.png
#   inflating: ship/1091.png
#   inflating: ship/6181.png
#   inflating: ship/8177.png
#   inflating: ship/2574.png
#   inflating: ship/9508.png
#   inflating: ship/823.png
#   inflating: ship/7222.png
#   inflating: ship/5138.png
#   inflating: ship/6030.png
#   inflating: ship/2725.png
#   inflating: ship/4444.png
#   inflating: ship/5466.png
#   inflating: ship/8515.png
#   inflating: ship/1216.png
#   inflating: ship/5729.png
#   inflating: ship/8896.png
#   inflating: ship/2227.png
#   inflating: ship/999.png
#   inflating: ship/8975.png
#   inflating: ship/4636.png
#   inflating: ship/7868.png
#   inflating: ship/2953.png
#   inflating: ship/3046.png
#   inflating: ship/9398.png
#   inflating: ship/8041.png
#   inflating: ship/6540.png
#   inflating: ship/7793.png
#   inflating: ship/1482.png
#   inflating: ship/1422.png
#   inflating: ship/80.png
#   inflating: ship/480.png
#   inflating: ship/6798.png
#   inflating: ship/9889.png
#   inflating: ship/2139.png
#   inflating: ship/9867.png
#   inflating: ship/9114.png
#   inflating: ship/8843.png
#   inflating: ship/5263.png
#   inflating: ship/9306.png
#   inflating: ship/5770.png
#   inflating: ship/144.png
#   inflating: ship/8120.png
#   inflating: ship/5586.png
#   inflating: ship/985.png
#   inflating: ship/2399.png
#   inflating: ship/3886.png
#   inflating: ship/7261.png
#   inflating: ship/711.png
#   inflating: ship/233.png
#   inflating: ship/5892.png
#   inflating: ship/1286.png
#   inflating: ship/6484.png
#   inflating: ship/7995.png
#   inflating: ship/2039.png
#   inflating: ship/6453.png
#   inflating: ship/722.png
#   inflating: ship/6987.png
#   inflating: ship/8939.png
#   inflating: ship/2223.png
#   inflating: ship/214.png
#   inflating: ship/6861.png
#   inflating: ship/8229.png
#   inflating: ship/636.png
#   inflating: ship/9389.png
#   inflating: ship/8018.png
#   inflating: ship/8834.png
#   inflating: ship/4695.png
#   inflating: ship/8339.png
#   inflating: ship/9057.png
#   inflating: ship/6045.png
#   inflating: ship/9288.png
#   inflating: ship/7653.png
#   inflating: ship/9274.png
#   inflating: ship/6725.png
#   inflating: ship/8732.png
#   inflating: ship/5898.png
#   inflating: ship/5500.png
#   inflating: ship/7462.png
#   inflating: ship/4910.png
#   inflating: ship/552.png
#   inflating: ship/6321.png
#   inflating: ship/8507.png
#   inflating: ship/126.png
#   inflating: ship/1243.png
#   inflating: ship/977.png
#   inflating: ship/1059.png
#   inflating: ship/9279.png
#   inflating: ship/8329.png
#   inflating: ship/1676.png
#   inflating: ship/9611.png
#   inflating: ship/4498.png
#   inflating: ship/9604.png
#   inflating: ship/2021.png
#   inflating: ship/918.png
#   inflating: ship/5207.png
#   inflating: ship/92.png
#   inflating: ship/7185.png
#   inflating: ship/2323.png
#   inflating: ship/4095.png
#   inflating: ship/6280.png
#   inflating: ship/2896.png
#   inflating: ship/2421.png
#   inflating: ship/1750.png
#   inflating: ship/3331.png
#   inflating: ship/7832.png
#   inflating: ship/8223.png
#   inflating: ship/72.png
#   inflating: ship/7414.png
#   inflating: ship/2424.png
#   inflating: ship/6376.png
#   inflating: ship/7934.png
#   inflating: ship/8186.png
#   inflating: ship/3869.png
#   inflating: ship/7392.png
#   inflating: ship/9669.png
#   inflating: ship/4881.png
#   inflating: ship/5398.png
#   inflating: ship/9719.png
#   inflating: ship/8431.png
#   inflating: ship/908.png
#   inflating: ship/3515.png
#   inflating: ship/2159.png
#   inflating: ship/5088.png
#   inflating: ship/1540.png
#   inflating: ship/8546.png
#   inflating: ship/6432.png
#   inflating: ship/5896.png
#   inflating: ship/3749.png
#   inflating: ship/7464.png
#   inflating: ship/6914.png
#   inflating: ship/8411.png
#   inflating: ship/1510.png
#   inflating: ship/3151.png
#   inflating: ship/8441.png
#   inflating: ship/8106.png
#   inflating: ship/5610.png
#   inflating: ship/6490.png
#   inflating: ship/9010.png
#   inflating: ship/3318.png
#   inflating: ship/4086.png
#   inflating: ship/5485.png
#   inflating: ship/9790.png
#   inflating: ship/2196.png
#   inflating: ship/242.png
#   inflating: ship/1159.png
#   inflating: ship/3653.png
#   inflating: ship/4812.png
#   inflating: ship/3072.png
#   inflating: ship/7536.png
#   inflating: ship/5836.png
#   inflating: ship/5020.png
#   inflating: ship/6155.png
#   inflating: ship/3078.png
#   inflating: ship/2245.png
#   inflating: ship/1122.png
#   inflating: ship/815.png
#   inflating: ship/7621.png
#   inflating: ship/724.png
#   inflating: ship/2398.png
#   inflating: ship/9932.png
#   inflating: ship/9206.png
#   inflating: ship/6794.png
#   inflating: ship/5747.png
#   inflating: ship/3385.png
#   inflating: ship/1002.png
#   inflating: ship/9418.png
#   inflating: ship/6776.png
#   inflating: ship/4251.png
#   inflating: ship/401.png
#   inflating: ship/5814.png
#   inflating: ship/8259.png
#   inflating: ship/6125.png
#   inflating: ship/6754.png
#   inflating: ship/5766.png
#   inflating: ship/9183.png
#   inflating: ship/7047.png
#   inflating: ship/4692.png
#   inflating: ship/1508.png
#   inflating: ship/7142.png
#   inflating: ship/1687.png
#   inflating: ship/9986.png
#   inflating: ship/9885.png
#   inflating: ship/3834.png
#   inflating: ship/4972.png
#   inflating: ship/4533.png
#   inflating: ship/3108.png
#   inflating: ship/1860.png
#   inflating: ship/6115.png
#   inflating: ship/8151.png
#   inflating: ship/5847.png
#   inflating: ship/5623.png
#   inflating: ship/1613.png
#   inflating: ship/7599.png
#   inflating: ship/6379.png
#   inflating: ship/3562.png
#   inflating: ship/2799.png
#   inflating: ship/3821.png
#   inflating: ship/8379.png
#   inflating: ship/482.png
#   inflating: ship/6950.png
#   inflating: ship/1943.png
#   inflating: ship/7525.png
#   inflating: ship/1259.png
#   inflating: ship/6141.png
#   inflating: ship/8393.png
#   inflating: ship/469.png
#   inflating: ship/4198.png
#   inflating: ship/6751.png
#   inflating: ship/2527.png
#   inflating: ship/6847.png
#   inflating: ship/9955.png
#   inflating: ship/2604.png
#   inflating: ship/1490.png
#   inflating: ship/5662.png
#   inflating: ship/1101.png
#   inflating: ship/306.png
#   inflating: ship/1160.png
#   inflating: ship/5648.png
#   inflating: ship/1419.png
#   inflating: ship/5614.png
#   inflating: ship/3938.png
#   inflating: ship/8644.png
#   inflating: ship/3817.png
#   inflating: ship/9200.png
#   inflating: ship/1833.png
#   inflating: ship/8994.png
#   inflating: ship/9158.png
#   inflating: ship/9347.png
#   inflating: ship/7790.png
#   inflating: ship/3531.png
#   inflating: ship/6829.png
#   inflating: ship/7033.png
#   inflating: ship/9785.png
#   inflating: ship/1805.png
#   inflating: ship/1994.png
#   inflating: ship/5277.png
#   inflating: ship/3279.png
#   inflating: ship/9572.png
#   inflating: ship/9220.png
#   inflating: ship/8614.png
#   inflating: ship/1205.png
#   inflating: ship/4370.png
#   inflating: ship/2135.png
#   inflating: ship/368.png
#   inflating: ship/150.png
#   inflating: ship/4006.png
#   inflating: ship/4222.png
#   inflating: ship/9371.png
#   inflating: ship/8418.png
#   inflating: ship/7459.png
#   inflating: ship/4300.png
#   inflating: ship/3476.png
#   inflating: ship/8679.png
#   inflating: ship/1512.png
#   inflating: ship/3226.png
#   inflating: ship/9054.png
#   inflating: ship/4258.png
#   inflating: ship/8725.png
#   inflating: ship/8653.png
#   inflating: ship/859.png
#   inflating: ship/5954.png
#   inflating: ship/9051.png
#   inflating: ship/3502.png
#   inflating: ship/8878.png
#   inflating: ship/4709.png
#   inflating: ship/5821.png
#   inflating: ship/7303.png
#   inflating: ship/7247.png
#   inflating: ship/6296.png
#   inflating: ship/3265.png
#   inflating: ship/6366.png
#   inflating: ship/2600.png
#   inflating: ship/3233.png
#   inflating: ship/3950.png
#   inflating: ship/3994.png
#   inflating: ship/408.png
#   inflating: ship/1532.png
#   inflating: ship/7643.png
#   inflating: ship/9900.png
#   inflating: ship/6743.png
#   inflating: ship/2511.png
#   inflating: ship/4869.png
#   inflating: ship/5621.png
#   inflating: ship/8407.png
#   inflating: ship/9405.png
#   inflating: ship/7447.png
#   inflating: ship/5531.png
#   inflating: ship/3037.png
#   inflating: ship/2420.png
#   inflating: ship/9792.png
#   inflating: ship/1218.png
#   inflating: ship/7707.png
#   inflating: ship/3813.png
#   inflating: ship/6765.png
#   inflating: ship/6179.png
#   inflating: ship/1262.png
#   inflating: ship/2492.png
#   inflating: ship/8256.png
#   inflating: ship/1111.png
#   inflating: ship/4455.png
#   inflating: ship/7252.png
#   inflating: ship/8583.png
#   inflating: ship/2.png
#   inflating: ship/2745.png
#   inflating: ship/1223.png
#   inflating: ship/9948.png
#   inflating: ship/337.png
#   inflating: ship/2870.png
#   inflating: ship/9105.png
#   inflating: ship/6730.png
#   inflating: ship/5920.png
#   inflating: ship/2284.png
#   inflating: ship/6124.png
#   inflating: ship/310.png
#   inflating: ship/8607.png
#   inflating: ship/2293.png
#   inflating: ship/8254.png
#   inflating: ship/6402.png
#   inflating: ship/7655.png
#   inflating: ship/4911.png
#   inflating: ship/2194.png
#   inflating: ship/1471.png
#   inflating: ship/7580.png
#   inflating: ship/1820.png
#   inflating: ship/1778.png
#   inflating: ship/9018.png
#   inflating: ship/3974.png
#   inflating: ship/7600.png
#   inflating: ship/1900.png
#   inflating: ship/3430.png
#   inflating: ship/2156.png
#   inflating: ship/992.png
#   inflating: ship/4125.png
#   inflating: ship/9810.png
#   inflating: ship/4494.png
#   inflating: ship/7502.png
#   inflating: ship/7706.png
#   inflating: ship/7695.png
#   inflating: ship/5777.png
#   inflating: ship/7796.png
#   inflating: ship/6395.png
#   inflating: ship/3205.png
#   inflating: ship/8602.png
#   inflating: ship/7361.png
#   inflating: ship/5418.png
#   inflating: ship/6594.png
#   inflating: ship/2007.png
#   inflating: ship/4280.png
#   inflating: ship/5294.png
#   inflating: ship/3138.png
#   inflating: ship/8890.png
#   inflating: ship/5793.png
#   inflating: ship/8809.png
#   inflating: ship/1685.png
#   inflating: ship/8531.png
#   inflating: ship/6411.png
#   inflating: ship/7485.png
#   inflating: ship/8137.png
#   inflating: ship/7765.png
#   inflating: ship/3383.png
#   inflating: ship/2713.png
#   inflating: ship/1783.png
#   inflating: ship/4865.png
#   inflating: ship/1331.png
#   inflating: ship/6684.png
#   inflating: ship/9412.png
#   inflating: ship/6112.png
#   inflating: ship/3729.png
#   inflating: ship/2736.png
#   inflating: ship/2169.png
#   inflating: ship/1983.png
#   inflating: ship/2962.png
#   inflating: ship/3366.png
#   inflating: ship/8159.png
#   inflating: ship/4385.png
#   inflating: ship/1809.png
#   inflating: ship/4199.png
#   inflating: ship/2593.png
#   inflating: ship/6524.png
#   inflating: ship/3698.png
#   inflating: ship/5457.png
#   inflating: ship/1856.png
#   inflating: ship/124.png
#   inflating: ship/9846.png
#   inflating: ship/7575.png
#   inflating: ship/9491.png
#   inflating: ship/8439.png
#   inflating: ship/4813.png
#   inflating: ship/9233.png
#   inflating: ship/3403.png
#   inflating: ship/9130.png
#   inflating: ship/2935.png
#   inflating: ship/3630.png
#   inflating: ship/1917.png
#   inflating: ship/2919.png
#   inflating: ship/8655.png
#   inflating: ship/1938.png
#   inflating: ship/6070.png
#   inflating: ship/9897.png
#   inflating: ship/7217.png
#   inflating: ship/1729.png
#   inflating: ship/8269.png
#   inflating: ship/1004.png
#   inflating: ship/4145.png
#   inflating: ship/600.png
#   inflating: ship/8152.png
#   inflating: ship/4115.png
#   inflating: ship/9568.png
#   inflating: ship/9995.png
#   inflating: ship/5791.png
#   inflating: ship/8581.png
#   inflating: ship/1772.png
#   inflating: ship/8246.png
#   inflating: ship/3289.png
#   inflating: ship/4539.png
#   inflating: ship/7576.png
#   inflating: ship/7782.png
#   inflating: ship/362.png
#   inflating: ship/9769.png
#   inflating: ship/218.png
#   inflating: ship/9370.png
#   inflating: ship/4649.png
#   inflating: ship/9343.png
#   inflating: ship/9240.png
#   inflating: ship/665.png
#   inflating: ship/5365.png
#   inflating: ship/3683.png
#   inflating: ship/8011.png
#   inflating: ship/5355.png
#   inflating: ship/7418.png
#   inflating: ship/1044.png
#   inflating: ship/694.png
#   inflating: ship/8294.png
#   inflating: ship/8460.png
#   inflating: ship/917.png
#   inflating: ship/9451.png
#   inflating: ship/7072.png
#   inflating: ship/7193.png
#   inflating: ship/4459.png
#   inflating: ship/5002.png
#   inflating: ship/8551.png
#   inflating: ship/8075.png
#   inflating: ship/2050.png
#   inflating: ship/3842.png
#   inflating: ship/8325.png
#   inflating: ship/4096.png
#   inflating: ship/7678.png
#   inflating: ship/612.png
#   inflating: ship/9532.png
#   inflating: ship/196.png
#   inflating: ship/703.png
#   inflating: ship/120.png
#   inflating: ship/8377.png
#   inflating: ship/6758.png
#   inflating: ship/5338.png
#   inflating: ship/4083.png
#   inflating: ship/3625.png
#   inflating: ship/8892.png
#   inflating: ship/6424.png
#   inflating: ship/6067.png
#   inflating: ship/9929.png
#   inflating: ship/4000.png
#   inflating: ship/9015.png
#   inflating: ship/9472.png
#   inflating: ship/7510.png
#   inflating: ship/6208.png
#   inflating: ship/6610.png
#   inflating: ship/3079.png
#   inflating: ship/4397.png
#   inflating: ship/3961.png
#   inflating: ship/4403.png
#   inflating: ship/4256.png
#   inflating: ship/9787.png
#   inflating: ship/3946.png
#   inflating: ship/2994.png
#   inflating: ship/2043.png
#   inflating: ship/6952.png
#   inflating: ship/2356.png
#   inflating: ship/4014.png
#   inflating: ship/9012.png
#   inflating: ship/403.png
#   inflating: ship/3123.png
#   inflating: ship/9266.png
#   inflating: ship/7396.png
#   inflating: deer/3297.png
#   inflating: deer/8801.png
#   inflating: deer/9541.png
#   inflating: deer/8944.png
#   inflating: deer/4049.png
#   inflating: deer/9335.png
#   inflating: deer/3600.png
#   inflating: deer/8711.png
#   inflating: deer/9668.png
#   inflating: deer/5004.png
#   inflating: deer/5296.png
#   inflating: deer/7537.png
#   inflating: deer/5172.png
#   inflating: deer/4344.png
#   inflating: deer/8540.png
#   inflating: deer/2641.png
#   inflating: deer/1533.png
#   inflating: deer/5863.png
#   inflating: deer/9119.png
#   inflating: deer/860.png
#   inflating: deer/3616.png
#   inflating: deer/466.png
#   inflating: deer/8479.png
#   inflating: deer/4573.png
#   inflating: deer/8180.png
#   inflating: deer/6664.png
#   inflating: deer/9104.png
#   inflating: deer/7896.png
#   inflating: deer/2611.png
#   inflating: deer/8699.png
#   inflating: deer/8452.png
#   inflating: deer/7957.png
#   inflating: deer/6497.png
#   inflating: deer/3054.png
#   inflating: deer/2917.png
#   inflating: deer/6454.png
#   inflating: deer/682.png
#   inflating: deer/9205.png
#   inflating: deer/9116.png
#   inflating: deer/2786.png
#   inflating: deer/5407.png
#   inflating: deer/3095.png
#   inflating: deer/1441.png
#   inflating: deer/8122.png
#   inflating: deer/4029.png
#   inflating: deer/5018.png
#   inflating: deer/7744.png
#   inflating: deer/1448.png
#   inflating: deer/1554.png
#   inflating: deer/5873.png
#   inflating: deer/7172.png
#   inflating: deer/735.png
#   inflating: deer/2961.png
#   inflating: deer/4488.png
#   inflating: deer/9771.png
#   inflating: deer/4902.png
#   inflating: deer/8612.png
#   inflating: deer/4847.png
#   inflating: deer/3827.png
#   inflating: deer/4031.png
#   inflating: deer/8058.png
#   inflating: deer/2869.png
#   inflating: deer/3436.png
#   inflating: deer/5177.png
#   inflating: deer/7239.png
#   inflating: deer/8280.png
#   inflating: deer/1541.png
#   inflating: deer/4604.png
#   inflating: deer/4985.png
#   inflating: deer/6665.png
#   inflating: deer/346.png
#   inflating: deer/2554.png
#   inflating: deer/5393.png
#   inflating: deer/26.png
#   inflating: deer/4213.png
#   inflating: deer/9163.png
#   inflating: deer/5008.png
#   inflating: deer/1693.png
#   inflating: deer/1350.png
#   inflating: deer/5888.png
#   inflating: deer/9858.png
#   inflating: deer/9321.png
#   inflating: deer/32.png
#   inflating: deer/8889.png
#   inflating: deer/5038.png
#   inflating: deer/2851.png
#   inflating: deer/8659.png
#   inflating: deer/2800.png
#   inflating: deer/4398.png
#   inflating: deer/4832.png
#   inflating: deer/8911.png
#   inflating: deer/1619.png
#   inflating: deer/4679.png
#   inflating: deer/3326.png
#   inflating: deer/7204.png
#   inflating: deer/5208.png
#   inflating: deer/8599.png
#   inflating: deer/188.png
#   inflating: deer/6396.png
#   inflating: deer/8071.png
#   inflating: deer/1911.png
#   inflating: deer/7298.png
#   inflating: deer/1741.png
#   inflating: deer/1765.png
#   inflating: deer/8556.png
#   inflating: deer/4114.png
#   inflating: deer/5634.png
#   inflating: deer/8069.png
#   inflating: deer/370.png
#   inflating: deer/9610.png
#   inflating: deer/9555.png
#   inflating: deer/455.png
#   inflating: deer/1272.png
#   inflating: deer/9187.png
#   inflating: deer/6918.png
#   inflating: deer/9627.png
#   inflating: deer/2858.png
#   inflating: deer/324.png
#   inflating: deer/328.png
#   inflating: deer/4683.png
#   inflating: deer/4137.png
#   inflating: deer/8486.png
#   inflating: deer/4002.png
#   inflating: deer/6822.png
#   inflating: deer/2403.png
#   inflating: deer/7978.png
#   inflating: deer/8647.png
#   inflating: deer/9981.png
#   inflating: deer/2805.png
#   inflating: deer/2595.png
#   inflating: deer/3276.png
#   inflating: deer/4821.png
#   inflating: deer/314.png
#   inflating: deer/5414.png
#   inflating: deer/8914.png
#   inflating: deer/5931.png
#   inflating: deer/2208.png
#   inflating: deer/6757.png
#   inflating: deer/5515.png
#   inflating: deer/1570.png
#   inflating: deer/5539.png
#   inflating: deer/3790.png
#   inflating: deer/6447.png
#   inflating: deer/6190.png
#   inflating: deer/2025.png
#   inflating: deer/2971.png
#   inflating: deer/6479.png
#   inflating: deer/3457.png
#   inflating: deer/1674.png
#   inflating: deer/714.png
#   inflating: deer/1484.png
#   inflating: deer/6622.png
#   inflating: deer/7029.png
#   inflating: deer/1443.png
#   inflating: deer/4220.png
#   inflating: deer/1186.png
#   inflating: deer/4794.png
#   inflating: deer/9506.png
#   inflating: deer/835.png
#   inflating: deer/9417.png
#   inflating: deer/1730.png
#   inflating: deer/6682.png
#   inflating: deer/1592.png
#   inflating: deer/7306.png
#   inflating: deer/2623.png
#   inflating: deer/580.png
#   inflating: deer/8309.png
#   inflating: deer/2180.png
#   inflating: deer/4608.png
#   inflating: deer/5415.png
#   inflating: deer/7735.png
#   inflating: deer/6750.png
#   inflating: deer/4227.png
#   inflating: deer/5912.png
#   inflating: deer/5329.png
#   inflating: deer/1393.png
#   inflating: deer/509.png
#   inflating: deer/6246.png
#   inflating: deer/1462.png
#   inflating: deer/4960.png
#   inflating: deer/5582.png
#   inflating: deer/7702.png
#   inflating: deer/5932.png
#   inflating: deer/8375.png
#   inflating: deer/3375.png
#   inflating: deer/1522.png
#   inflating: deer/6012.png
#   inflating: deer/2283.png
#   inflating: deer/769.png
#   inflating: deer/889.png
#   inflating: deer/7726.png
#   inflating: deer/3127.png
#   inflating: deer/7273.png
#   inflating: deer/2280.png
#   inflating: deer/465.png
#   inflating: deer/9330.png
#   inflating: deer/1249.png
#   inflating: deer/4111.png
#   inflating: deer/6753.png
#   inflating: deer/3120.png
#   inflating: deer/6129.png
#   inflating: deer/3696.png
#   inflating: deer/441.png
#   inflating: deer/9511.png
#   inflating: deer/2030.png
#   inflating: deer/3346.png
#   inflating: deer/9765.png
#   inflating: deer/7403.png
#   inflating: deer/5262.png
#   inflating: deer/9972.png
#   inflating: deer/6916.png
#   inflating: deer/2182.png
#   inflating: deer/7081.png
#   inflating: deer/5959.png
#   inflating: deer/7408.png
#   inflating: deer/6902.png
#   inflating: deer/5878.png
#   inflating: deer/2785.png
#   inflating: deer/9536.png
#   inflating: deer/2191.png
#   inflating: deer/3877.png
#   inflating: deer/4578.png
#   inflating: deer/4065.png
#   inflating: deer/9597.png
#   inflating: deer/2719.png
#   inflating: deer/1658.png
#   inflating: deer/3203.png
#   inflating: deer/2981.png
#   inflating: deer/6572.png
#   inflating: deer/4173.png
#   inflating: deer/8695.png
#   inflating: deer/1015.png
#   inflating: deer/8989.png
#   inflating: deer/3526.png
#   inflating: deer/278.png
#   inflating: deer/2605.png
#   inflating: deer/7308.png
#   inflating: deer/2069.png
#   inflating: deer/1944.png
#   inflating: deer/8080.png
#   inflating: deer/295.png
#   inflating: deer/3292.png
#   inflating: deer/2523.png
#   inflating: deer/5919.png
#   inflating: deer/9128.png
#   inflating: deer/463.png
#   inflating: deer/5145.png
#   inflating: deer/3004.png
#   inflating: deer/3910.png
#   inflating: deer/9139.png
#   inflating: deer/1971.png
#   inflating: deer/3069.png
#   inflating: deer/130.png
#   inflating: deer/8086.png
#   inflating: deer/5316.png
#   inflating: deer/5239.png
#   inflating: deer/2353.png
#   inflating: deer/2766.png
#   inflating: deer/7238.png
#   inflating: deer/5702.png
#   inflating: deer/7921.png
# ...
#   inflating: automobile/7053.png
#   inflating: automobile/1187.png
#   inflating: automobile/1969.png
#   inflating: automobile/1229.png
#   inflating: automobile/7169.png
#   inflating: automobile/3162.png
#   inflating: automobile/9811.png
#   inflating: automobile/8214.png
#   inflating: automobile/6701.png
#   inflating: automobile/764.png
#   inflating: automobile/369.png
#   inflating: automobile/7280.png
#   inflating: automobile/8494.png
#   inflating: automobile/1005.png
#   inflating: automobile/4430.png
#   inflating: automobile/1021.png
#   inflating: automobile/5396.png
#   inflating: automobile/9907.png
#   inflating: automobile/1185.png
#   inflating: automobile/3485.png
#   inflating: automobile/5449.png
#   inflating: automobile/3988.png
#   inflating: automobile/1047.png
#   inflating: automobile/7236.png
#   inflating: automobile/6281.png
#   inflating: automobile/5685.png
#   inflating: automobile/5233.png
#   inflating: automobile/9609.png
#   inflating: automobile/9739.png
#   inflating: automobile/4236.png
#   inflating: automobile/6182.png
#   inflating: automobile/968.png
#   inflating: automobile/286.png
#   inflating: automobile/5667.png
#   inflating: automobile/3730.png
#   inflating: automobile/7909.png
#   inflating: automobile/9368.png
#   inflating: automobile/645.png
#   inflating: automobile/9634.png
#   inflating: automobile/753.png
#   inflating: automobile/1182.png
#   inflating: automobile/6150.png
#   inflating: automobile/1016.png
#   inflating: automobile/5217.png
#   inflating: automobile/6195.png
#   inflating: automobile/201.png
#   inflating: automobile/1786.png
#   inflating: automobile/7133.png
#   inflating: automobile/8751.png
#   inflating: automobile/7943.png
#   inflating: automobile/9232.png
#   inflating: automobile/9788.png
#   inflating: automobile/4285.png
#   inflating: automobile/894.png
#   inflating: automobile/619.png
#   inflating: automobile/2694.png
#   inflating: automobile/1340.png
#   inflating: automobile/4015.png
#   inflating: automobile/7243.png
#   inflating: automobile/2607.png
#   inflating: automobile/5918.png
#   inflating: automobile/8709.png
#   inflating: automobile/8391.png
#   inflating: automobile/1301.png
#   inflating: automobile/8155.png
#   inflating: automobile/9125.png
#   inflating: automobile/6728.png
#   inflating: automobile/6767.png
#   inflating: automobile/5474.png
#   inflating: automobile/2520.png
#   inflating: automobile/4466.png
#   inflating: automobile/4543.png
#   inflating: automobile/1784.png
#   inflating: automobile/3039.png
#   inflating: automobile/3632.png
#   inflating: automobile/2439.png
#   inflating: automobile/9457.png
#   inflating: automobile/7363.png
#   inflating: automobile/9179.png
#   inflating: automobile/4992.png
#   inflating: automobile/7953.png
#   inflating: automobile/8139.png
#   inflating: automobile/7898.png
#   inflating: automobile/738.png
#   inflating: automobile/8522.png
#   inflating: automobile/4532.png
#   inflating: automobile/2859.png
#   inflating: automobile/8053.png
#   inflating: automobile/8674.png
#   inflating: automobile/1098.png
#   inflating: automobile/6886.png
#   inflating: automobile/7840.png
#   inflating: automobile/305.png
#   inflating: automobile/5799.png
#   inflating: automobile/1174.png
#   inflating: automobile/6130.png
#   inflating: automobile/3544.png
#   inflating: automobile/1769.png
#   inflating: automobile/513.png
#   inflating: automobile/82.png
#   inflating: automobile/5678.png
#   inflating: automobile/7532.png
#   inflating: automobile/3772.png
#   inflating: automobile/8648.png
#   inflating: automobile/4166.png
#   inflating: automobile/7272.png
#   inflating: automobile/3080.png
#   inflating: automobile/9865.png
#   inflating: automobile/9510.png
#   inflating: automobile/3527.png
#   inflating: automobile/9794.png
#   inflating: automobile/759.png
#   inflating: automobile/8678.png
#   inflating: automobile/8839.png
#   inflating: automobile/6431.png
#   inflating: automobile/8504.png
#   inflating: automobile/6984.png
#   inflating: automobile/9593.png
#   inflating: automobile/4890.png
#   inflating: automobile/7021.png
#   inflating: automobile/9916.png
#   inflating: automobile/5270.png
#   inflating: automobile/1238.png
#   inflating: automobile/4822.png
#   inflating: automobile/830.png
#   inflating: automobile/4949.png
#   inflating: automobile/3611.png
#   inflating: automobile/906.png
#   inflating: automobile/5375.png
#   inflating: automobile/7759.png
#   inflating: automobile/5243.png
#   inflating: automobile/9935.png
#   inflating: automobile/414.png
#   inflating: automobile/2462.png
#   inflating: automobile/9211.png
#   inflating: automobile/4067.png
#   inflating: automobile/3921.png
#   inflating: automobile/6084.png
#   inflating: automobile/4875.png
#   inflating: automobile/7964.png
#   inflating: automobile/3500.png
#   inflating: automobile/6991.png
#   inflating: automobile/4206.png
#   inflating: automobile/2164.png
#   inflating: automobile/7052.png
#   inflating: automobile/5214.png
#   inflating: automobile/7274.png
#   inflating: automobile/7937.png
#   inflating: automobile/4128.png
#   inflating: automobile/2987.png
#   inflating: automobile/3362.png
#   inflating: automobile/6639.png
#   inflating: automobile/5882.png
#   inflating: automobile/7674.png
#   inflating: automobile/2294.png
#   inflating: automobile/4135.png
#   inflating: automobile/8498.png
#   inflating: automobile/8388.png
#   inflating: automobile/7017.png
#   inflating: automobile/3553.png
#   inflating: automobile/726.png
#   inflating: automobile/6430.png
#   inflating: automobile/8593.png
#   inflating: automobile/1747.png
#   inflating: automobile/9824.png
#   inflating: automobile/5051.png
#   inflating: automobile/6086.png
#   inflating: automobile/1020.png
#   inflating: automobile/7376.png
#   inflating: automobile/2784.png
#   inflating: automobile/1633.png
#   inflating: automobile/5380.png
#   inflating: automobile/7889.png
#   inflating: automobile/2928.png
#   inflating: automobile/1493.png
#   inflating: automobile/5024.png
#   inflating: automobile/8372.png
#   inflating: automobile/4506.png
#   inflating: automobile/5353.png
#   inflating: automobile/7565.png
#   inflating: automobile/1970.png
#   inflating: automobile/9178.png
#   inflating: automobile/8138.png
#   inflating: automobile/7734.png
#   inflating: automobile/6493.png
#   inflating: automobile/4647.png
#   inflating: automobile/8880.png
#   inflating: automobile/104.png
#   inflating: automobile/5348.png
#   inflating: automobile/4841.png
#   inflating: automobile/2645.png
#   inflating: automobile/4431.png
#   inflating: automobile/1684.png
#   inflating: automobile/4371.png
#   inflating: automobile/7063.png
#   inflating: automobile/4059.png
#   inflating: automobile/7946.png
#   inflating: automobile/5718.png
#   inflating: automobile/3293.png
#   inflating: automobile/2757.png
#   inflating: automobile/4080.png
#   inflating: automobile/2009.png
#   inflating: automobile/7656.png
#   inflating: automobile/9687.png
#   inflating: automobile/5905.png
#   inflating: automobile/8035.png
#   inflating: automobile/6858.png
#   inflating: automobile/5480.png
#   inflating: automobile/6410.png
#   inflating: automobile/7324.png
#   inflating: automobile/7208.png
#   inflating: automobile/407.png
#   inflating: automobile/5226.png
#   inflating: automobile/6371.png
#   inflating: automobile/3215.png
#   inflating: automobile/390.png
#   inflating: automobile/8640.png
#   inflating: automobile/9800.png
#   inflating: automobile/2636.png
#   inflating: automobile/1313.png
#   inflating: automobile/5132.png
#   inflating: automobile/4288.png
#   inflating: automobile/8445.png
#   inflating: automobile/9245.png
#   inflating: automobile/771.png
#   inflating: automobile/1141.png
#   inflating: automobile/8248.png
#   inflating: automobile/9580.png
#   inflating: automobile/3152.png
#   inflating: automobile/5483.png
#   inflating: automobile/9110.png
#   inflating: automobile/6048.png
#   inflating: automobile/8959.png
#   inflating: automobile/7572.png
#   inflating: automobile/9432.png
#   inflating: automobile/8621.png
#   inflating: automobile/2258.png
#   inflating: automobile/801.png
#   inflating: automobile/9696.png
#   inflating: automobile/440.png
#   inflating: automobile/9588.png
#   inflating: automobile/3560.png
#   inflating: automobile/4613.png
#   inflating: automobile/7749.png
#   inflating: automobile/6659.png
#   inflating: automobile/8123.png
#   inflating: automobile/1740.png
#   inflating: automobile/8304.png
#   inflating: automobile/6655.png
#   inflating: automobile/7098.png
#   inflating: automobile/1413.png
#   inflating: automobile/161.png
#   inflating: automobile/2086.png
#   inflating: automobile/2813.png
#   inflating: automobile/1378.png
#   inflating: automobile/8564.png
#   inflating: automobile/7129.png
#   inflating: automobile/6742.png
#   inflating: automobile/6464.png
#   inflating: automobile/9265.png
#   inflating: automobile/3074.png
#   inflating: automobile/2346.png
#   inflating: automobile/2179.png
#   inflating: automobile/4372.png
#   inflating: automobile/7862.png
#   inflating: automobile/1270.png
#   inflating: automobile/9592.png
#   inflating: automobile/8495.png
#   inflating: automobile/6806.png
#   inflating: automobile/2063.png
#   inflating: automobile/5318.png
#   inflating: automobile/9016.png
#   inflating: automobile/3012.png
#   inflating: automobile/1048.png
#   inflating: automobile/6940.png
#   inflating: automobile/4318.png
#   inflating: automobile/2369.png
#   inflating: automobile/2620.png
#   inflating: automobile/4516.png
#   inflating: automobile/4838.png
#   inflating: automobile/7472.png
#   inflating: automobile/7555.png
#   inflating: automobile/3246.png
#   inflating: automobile/5598.png
#   inflating: automobile/66.png
#   inflating: automobile/8517.png
#   inflating: automobile/2289.png
#   inflating: automobile/3175.png
#   inflating: automobile/8907.png
#   inflating: automobile/3165.png
#   inflating: automobile/1711.png
#   inflating: automobile/2438.png
#   inflating: automobile/3001.png
#   inflating: automobile/6372.png
#   inflating: automobile/9427.png
#   inflating: automobile/4274.png
#   inflating: automobile/5723.png
#   inflating: automobile/1907.png
#   inflating: automobile/2601.png
#   inflating: automobile/4999.png
#   inflating: automobile/9373.png
#   inflating: automobile/4378.png
#   inflating: automobile/2906.png
#   inflating: automobile/5058.png
#   inflating: automobile/3826.png
#   inflating: automobile/7156.png
#   inflating: automobile/193.png
#   inflating: automobile/3122.png
#   inflating: automobile/6251.png
#   inflating: automobile/7516.png
#   inflating: automobile/3471.png
#   inflating: automobile/2504.png
#   inflating: automobile/7577.png
#   inflating: automobile/1258.png
#   inflating: automobile/8097.png
#   inflating: automobile/4752.png
#   inflating: automobile/6817.png
#   inflating: automobile/2947.png
#   inflating: automobile/4850.png
#   inflating: automobile/4806.png
#   inflating: automobile/7473.png
#   inflating: automobile/941.png
#   inflating: automobile/5563.png
#   inflating: automobile/3904.png
#   inflating: automobile/8866.png
#   inflating: automobile/4790.png
#   inflating: automobile/3855.png
#   inflating: automobile/9001.png
#   inflating: automobile/4766.png
#   inflating: automobile/9998.png
#   inflating: automobile/6638.png
#   inflating: automobile/8366.png
#   inflating: automobile/5019.png
#   inflating: automobile/7035.png
#   inflating: automobile/5517.png
#   inflating: automobile/6451.png
#   inflating: automobile/6417.png
#   inflating: automobile/4755.png
#   inflating: automobile/4602.png
#   inflating: automobile/3150.png
#   inflating: automobile/4799.png
#   inflating: automobile/4741.png
#   inflating: automobile/7901.png
#   inflating: automobile/7394.png
#   inflating: automobile/5470.png
#   inflating: automobile/8623.png
#   inflating: automobile/7973.png
#   inflating: automobile/6536.png
#   inflating: automobile/3579.png
#   inflating: automobile/4895.png
#   inflating: automobile/656.png
#   inflating: automobile/997.png
#   inflating: automobile/6788.png
#   inflating: automobile/2838.png
#   inflating: automobile/2647.png
#   inflating: automobile/9905.png
#   inflating: automobile/2740.png
#   inflating: automobile/8056.png
#   inflating: automobile/4863.png
#   inflating: automobile/8455.png
#   inflating: automobile/947.png
#   inflating: automobile/8945.png
#   inflating: automobile/1232.png
#   inflating: automobile/3372.png
#   inflating: automobile/3629.png
#   inflating: automobile/4736.png
#   inflating: automobile/3645.png
#   inflating: automobile/3963.png
#   inflating: automobile/1176.png
#   inflating: automobile/6552.png
#   inflating: automobile/3814.png
#   inflating: automobile/4207.png
#   inflating: automobile/1716.png
#   inflating: automobile/3663.png
#   inflating: automobile/5079.png
#   inflating: automobile/6555.png
#   inflating: automobile/1115.png
#   inflating: automobile/5803.png
#   inflating: automobile/6117.png
#   inflating: automobile/3144.png
#   inflating: automobile/8261.png
#   inflating: automobile/6643.png
#   inflating: automobile/6100.png
#   inflating: automobile/1706.png
#   inflating: automobile/6415.png
#   inflating: automobile/4245.png
#   inflating: automobile/2220.png
#   inflating: automobile/2357.png
#   inflating: automobile/131.png
#   inflating: automobile/9974.png
#   inflating: automobile/4441.png
#   inflating: automobile/9.png
#   inflating: automobile/5970.png
#   inflating: automobile/9126.png
#   inflating: automobile/1761.png
#   inflating: automobile/895.png
#   inflating: automobile/736.png
#   inflating: automobile/7638.png
#   inflating: automobile/6492.png
#   inflating: automobile/5245.png
#   inflating: automobile/7260.png
#   inflating: automobile/9807.png
#   inflating: automobile/6843.png
#   inflating: automobile/3028.png
#   inflating: automobile/105.png
#   inflating: automobile/6995.png
#   inflating: automobile/1504.png
#   inflating: automobile/3370.png
#   inflating: automobile/1408.png
#   inflating: automobile/3105.png
#   inflating: automobile/366.png
#   inflating: automobile/961.png
#   inflating: automobile/1212.png
#   inflating: automobile/9626.png
#   inflating: automobile/7728.png
#   inflating: automobile/1923.png
#   inflating: automobile/9662.png
#   inflating: automobile/7173.png
#   inflating: automobile/1882.png
#   inflating: automobile/9421.png
#   inflating: automobile/3612.png

# %% [markdown]
# **Now we look at the effect of scrambled images on the accuracy**:
# Here we load in the cifar10 dataset with scrambled images

# %%
dataset = CIFAR10GCustomDataset(root_dir=data_dir, class_map=class_map, transform=transform)

test_loader = DataLoader(dataset, batch_size=32, shuffle=False, num_workers=4)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# Here we validate the model on this dataset with scrambled. we will then compare the accuracies with and without scrambled images in the cifar10 dataset and evaluate how much the accuracy drops of our model

# %%
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for images, labels in tqdm(test_loader, desc="Validating", unit="batch"):

        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total

print(f'Validation Accuracy: {accuracy:.2f}%')
print("Change in accuracy: ", cifar10acc - accuracy)
# Out:
# Validating:   0%|          | 0/313 [00:00<?, ?batch/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Validating: 100%|██████████| 313/313 [00:59<00:00,  5.22batch/s]
# Validation Accuracy: 20.56%
# Change in accuracy:  62.41

# %%
# !unzip cifar10_styled_100.zip
# Out:
# Archive:  cifar10_styled_100.zip
#   inflating: styled_image_0_20.png
#   inflating: styled_image_5_45.png
#   inflating: styled_image_2_59.png
#   inflating: styled_image_9_71.png
#   inflating: styled_image_0_72.png
#   inflating: styled_image_9_29.png
#   inflating: styled_image_6_69.png
#   inflating: styled_image_7_28.png
#   inflating: styled_image_1_78.png
#   inflating: styled_image_6_84.png
#   inflating: styled_image_6_80.png
#   inflating: styled_image_1_75.png
#   inflating: styled_image_2_47.png
#   inflating: styled_image_7_12.png
#   inflating: styled_image_5_93.png
#   inflating: styled_image_7_55.png
#   inflating: styled_image_6_13.png
#   inflating: styled_image_2_86.png
#   inflating: styled_image_8_44.png
#   inflating: styled_image_6_54.png
#   inflating: styled_image_3_65.png
#   inflating: styled_image_0_27.png
#   inflating: styled_image_9_48.png
#   inflating: styled_image_6_42.png
#   inflating: styled_image_2_38.png
#   inflating: styled_image_2_88.png
#   inflating: styled_image_4_68.png
#   inflating: styled_image_0_83.png
#   inflating: styled_image_7_61.png
#   inflating: styled_image_2_9.png
#   inflating: styled_image_8_56.png
#   inflating: styled_image_0_74.png
#   inflating: styled_image_6_8.png
#   inflating: styled_image_3_16.png
#   inflating: styled_image_3_95.png
#   inflating: styled_image_3_81.png
#   inflating: styled_image_8_63.png
#   inflating: styled_image_6_34.png
#   inflating: styled_image_1_14.png
#   inflating: styled_image_2_62.png
#   inflating: styled_image_2_15.png
#   inflating: styled_image_3_30.png
#   inflating: styled_image_7_40.png
#   inflating: styled_image_0_73.png
#   inflating: styled_image_2_32.png
#   inflating: styled_image_9_67.png
#   inflating: styled_image_0_7.png
#   inflating: styled_image_6_17.png
#   inflating: styled_image_5_57.png
#   inflating: styled_image_3_79.png
#   inflating: styled_image_5_39.png
#   inflating: styled_image_1_53.png
#   inflating: styled_image_9_4.png
#   inflating: styled_image_3_51.png
#   inflating: styled_image_1_19.png
#   inflating: styled_image_6_25.png
#   inflating: styled_image_5_1.png
#   inflating: styled_image_3_43.png
#   inflating: styled_image_6_90.png
#   inflating: styled_image_2_26.png
#   inflating: styled_image_4_60.png
#   inflating: styled_image_4_77.png
#   inflating: styled_image_4_24.png
#   inflating: styled_image_9_10.png
#   inflating: styled_image_5_98.png
#   inflating: styled_image_4_64.png
#   inflating: styled_image_8_36.png
#   inflating: styled_image_6_2.png
#   inflating: styled_image_7_41.png
#   inflating: styled_image_7_99.png
#   inflating: styled_image_3_94.png
#   inflating: styled_image_9_96.png
#   inflating: styled_image_3_21.png
#   inflating: styled_image_2_35.png
#   inflating: styled_image_7_37.png
#   inflating: styled_image_3_52.png
#   inflating: styled_image_4_89.png
#   inflating: styled_image_7_82.png
#   inflating: styled_image_5_66.png
#   inflating: styled_image_7_50.png
#   inflating: styled_image_7_46.png
#   inflating: styled_image_2_6.png
#   inflating: styled_image_3_91.png
#   inflating: styled_image_5_70.png
#   inflating: styled_image_5_33.png
#   inflating: styled_image_5_31.png
#   inflating: styled_image_6_92.png
#   inflating: styled_image_1_87.png
#   inflating: styled_image_1_49.png
#   inflating: styled_image_7_5.png
#   inflating: styled_image_2_22.png
#   inflating: styled_image_1_97.png
#   inflating: styled_image_8_18.png
#   inflating: styled_image_9_85.png
#   inflating: styled_image_1_3.png
#   inflating: styled_image_4_11.png
#   inflating: styled_image_1_0.png
#   inflating: styled_image_3_58.png
#   inflating: styled_image_6_76.png
#   inflating: styled_image_2_23.png

# %% [markdown]
# Global Style changes: First we created a dataset that had a style change modelled on cifar 10. the photo we used to introduce a style change was starry night by van gogh. We evaluate our model (trained on CIFAR10) on these new images. Moreover, we then calculate the change in accuracy after introducing a style change

# %%
class StyledImageDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform

        self.image_filenames = [f for f in os.listdir(root_dir) if f.startswith('styled_image_')]

    def __len__(self):
        return len(self.image_filenames)

    def __getitem__(self, idx):
        img_name = os.path.join(self.root_dir, self.image_filenames[idx])
        image = Image.open(img_name).convert('RGB')
        label = int(self.image_filenames[idx].split('_')[2].split('.')[0])

        if self.transform:
            image = self.transform(image)

        return image, label

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

styled_images_path = './'
dataset = StyledImageDataset(root_dir=styled_images_path, transform=transform)
dataloader = DataLoader(dataset, batch_size=1, shuffle=False)

model.to(device)
model.eval()

correct = 0
total = 0

with torch.no_grad():
    for images, labels in dataloader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

acc = 100 * correct / total
print(f'Accuracy: {100 * correct / total:.2f}%')
# Out:
# Accuracy: 19.00%

# %%
print("Drop in accuracy is: ", cifar10acc - acc)
# Out:
# Drop in accuracy is:  63.97
